# %%
from jax.config import config
config.update("jax_enable_x64", True)

import jax.numpy as jnp
from jax import jit, lax, vmap, jacobian
import jax.scipy.linalg as jsl

import jax

import numpy as np
from read_traj_v2 import *

import scipy.optimize
from tqdm import trange
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
mol = 'heh+'
basis = 'sto-3g'
init = 'hf'
td = 'rt-tdexx'

dt = 0.08268/10

inpath = './correctdata'
inpath2 = './mydata/'
outpath = './'
saved_model_dir = './models/'

trnfrq = jnp.array(np.load('./tdcis_data/tdcis_trnfreq_dt0.008268.npz'))
trnamp = jnp.array(np.load('./tdcis_data/tdcis_trnamp_dt0.008268.npz'))
trntme = jnp.array(np.load('./tdcis_data/tdcis_trntme_dt0.008268.npz'))
# load important static matrices
a = traj_data(inpath, mol, basis, init, td, '001',
                init_cond_file=f'ke+en+overlap+ee_twoe+dip_casscf22_{mol}_{basis}.npz',
                )
a.assign_init_data()
drc = a.drc
xmat, didat, kinmat, enmat = a.xmat, a.didat, a.kinmat, a.enmat
X = xmat
# Out:
# 	reading from "./correctdata/ke+en+overlap+ee_twoe+dip_casscf22_heh+_sto-3g.npz"
#
# can only concatenate str (not "NoneType") to str
# True is not in list

# %%
trnden = jnp.array(np.load('./tdcis_data/tdcis_dt0.0082680.npz'))
#trnden = jnp.array(np.load('./tdhf_data/rt-tdhf_forcing_full_finedt.npz'))
print(trnden.shape)
# Out:
# (301, 10000, 2, 2)

# %%
# inds = np.array([140, 141, 142, 143, 144, 150, 151, 152, 153,
#        154, 155, 156, 157, 158, 159, 165, 166, 167,168,169])
inds = np.array([145])
trnden = trnden[inds]
trnfrq = trnfrq[inds]
trnamp = trnamp[inds]
trntme = trntme[inds]

# %%
print(trnden.shape)
# Out:
# (1, 10000, 2, 2)

# %%
# overlapAO = np.array([[1.0, 0.538415], [0.538415, 1.0]])
# s, U = np.linalg.eig(overlapAO)
# dens = np.load('./tdcis_data/td_dens_tdcis_heh+_sto-3g_145_dt=0.082680au.npz')
# dens = dens['td_dens_re_data'] + 1j*dens['td_dens_im_data']

# %%
# high_dt = np.diag(np.sqrt(s))  @ U.T @ dens @ U @ np.diag(np.sqrt(s))
# high_dt = high_dt[:10000]

# %%
# myinfo(0)

# %%
# plt.plot(np.abs(np.fft.fft(trnden[0,:,0,0]))[:])
# plt.plot(np.abs(np.fft.fft(trnden[1,:,0,0]))[:])
# plt.legend(['low_amp', 'high_amp'])

# %%
# high_dt = np.diag(np.sqrt(s))  @ U.T @ dens @ U @ np.diag(np.sqrt(s))
# datatotal = high_dt
# acorrs = []
# re00 = datatotal[:,0,0].real
# re01 = datatotal[:,0,1].real
# im01 = datatotal[:,0,1].imag
# re11 = datatotal[:,1,1].real

# %%
# data = re11
# # Mean
# mean = np.mean(data)

# # Variance
# var = np.var(data)

# # Normalized data
# ndata = data - mean

# %%
# acorr = np.correlate(ndata, ndata, 'full')[len(ndata)-1:] 
# acorr = acorr / var / len(ndata)
# acorrs.append(acorr)

# %%
# for j in range(len(acorrs)):
#     plt.plot(acorrs[j])
#     plt.show()
#     plt.close()

# %%
# need two masks
# upper mask is matrix whose (u,v)-th element is 0 unless u <= v
# lower mask is matrix whose (u,v)-th element is 0 unless u > v
upper = np.zeros((2,2),dtype=np.float64)
lower = np.zeros((2,2),dtype=np.float64)
for u in range(2):
    for v in range(2):
        if u <= v:
            upper[u,v] = 1.0
        if u > v:
            lower[u,v] = 1.0

ru1 = 2*np.einsum('uv,uk,ma,sb,uvms,vl->klab',upper,X,X,X,a.eeten,X)
ru2 = np.einsum('uv,uk,ma,sb,umvs,vl->klab',upper,X,X,X,a.eeten,X)
rl1 = 2*np.einsum('uv,uk,ma,sb,vums,vl->klab',lower,X,X,X,a.eeten,X)
rl2 = np.einsum('uv,uk,ma,sb,vmus,vl->klab',lower,X,X,X,a.eeten,X)
beta1trueNP = ru1 - ru2 + rl1 - rl2
gamma1trueNP = ru1 - ru2 - rl1 + rl2

beta0trueNP = xmat.conj().T @ (kinmat - enmat) @ xmat
gamma0trueNP = np.zeros(beta0trueNP.shape)

# extract parameters for real target
beta0true = -beta0trueNP.reshape((-1))
beta1true = -beta1trueNP.reshape((drc**2, drc**2))
# extract parameters for imag target
gamma0true = -gamma0trueNP.reshape((-1))
gamma1true = -gamma1trueNP.reshape((drc**2, drc**2))

beta0 = beta0true
# beta1 = beta1true
gamma0 = gamma0true
# gamma1 = gamma1true

thetatrue = jnp.concatenate([beta1true.reshape((-1)), gamma1true.reshape((-1))])

# %%
# #nlayers = 2
# #layerwidths = [2*drc**2,164,164,164,2*drc**2]
# nlayers = 2
# layerwidths = [2*drc**2,1200,2*drc**2]
# numparams = 0
# numweights = 0
# for j in range(nlayers):
#     numparams += layerwidths[j]*layerwidths[j+1] + layerwidths[j+1]
#     numweights += layerwidths[j]*layerwidths[j+1]
numparams =  2*21 * drc**4 #+ 80  + 8 + 32
# # numparams = 32

# %%
def MLham(theta,t,x,y,memory_steps=[],fldfrq=0,fldamp=0,tmeoff=0,norm_direc=0):
    beta1 = thetatrue[:drc**4].reshape((drc**2, drc**2))
    gamma1 = thetatrue[drc**4:2*drc**4].reshape((drc**2, drc**2))
    
#     beta1prev = theta[:drc**4].reshape((drc**2, drc**2))
#     gamma1prev = theta[drc**4:2*drc**4].reshape((drc**2, drc**2))
    
#     beta1prev2= theta[2*drc**4: 3*drc**4].reshape((drc**2,drc**2))
#     gamma1prev2 = theta[3*drc**4:4*drc**4].reshape((drc**2,drc*2))
    
    x = x.reshape((drc**2))
    y = y.reshape((drc**2))
    
    rmat = (beta0 + jnp.matmul(x,beta1))
    qmat = (gamma0 + jnp.matmul(y,gamma1))
     
    if len(memory_steps) > 0:
        final_ind = -1
        for k in range(len(memory_steps)):
            xmk, ymk = memory_steps[k]
            xmk = xmk.reshape((drc**2))
            ymk = ymk.reshape((drc**2))
            # # produce real target
            rmat += ( jnp.matmul(theta[2*k*drc**4:(2*k+1)*drc**4].reshape((drc**2,drc**2)), xmk ))
            # # produce imag target
            qmat += ( jnp.matmul(theta[(2*k+1)*drc**4:(2*k+2)*drc**4].reshape((drc**2,drc**2)), ymk)) 
            final_ind = (2*k+2)*drc**4
#         p = x+1j*y
#         p2ndorder = jnp.array([p[0]**2, p[0]*p[1], p[0]*p[2], p[0]*p[3],p[1]**2, p[1]*p[2], p[1]*p[3], p[2]**2, p[2]*p[3], p[3]**2])
#         x2 = p2ndorder.real.reshape((10))
#         y2 = p2ndorder.imag.reshape((10))

#         beta2ndorder = theta[final_ind: final_ind+40].reshape((4,10))
#         gamma2ndorder = theta[final_ind+40:final_ind+80].reshape((4,10))
        
#         betalin = theta[final_ind+80:final_ind+96].reshape((drc**2,drc**2))
#         gammalin = theta[final_ind+96: final_ind+112].reshape((drc**2,drc**2))
        
#         betaint = theta[final_ind+112:final_ind+116].reshape((drc**2))
#         gammaint = theta[final_ind+116:final_ind+120].reshape((drc**2))
        

#         rmat += jnp.matmul(beta2ndorder,x2)
#         qmat += jnp.matmul(gamma2ndorder,y2)
        
#         rmat += betaint
#         qmat += gammaint
        
#         rmat += jnp.matmul(betalin, x)
#         qmat += jnp.matmul(gammalin, y)
        
    rmat = (rmat).reshape((drc,drc))
    qmat = (qmat).reshape((drc, drc))
    h = 0.5*(rmat + rmat.T) + 0.5j*(qmat - qmat.T)
    
    ef = (t>=0)*(t<=tmeoff)*fldamp*jnp.sin(fldfrq*t)
    hfieldAO = ef*jnp.sum(norm_direc[:,None,None]*didat, axis=0, dtype=jnp.complex128)
    h -= xmat.conj().T @ hfieldAO @ xmat
    return h.real, h.imag

# %%
mynumsteps = 1000
ntvec = mynumsteps

# %%
def MMUT_Prop_HSB(theta, initial_density, dt=0.08268, ntvec=2000,
                  tmeoff=1, fldfrq=1, fldamp=1, norm_direc=jnp.array([0.0,0.0,1.0])):
    tvec = dt*jnp.arange(ntvec)
    P0 = initial_density.reshape((drc, drc))
    propagated_dens = [P0]
    H0 = MLham(theta,0.0,P0.real, P0.imag,[],fldfrq,fldamp,tmeoff,norm_direc)
    H0 = H0[0] + 1.0j*H0[1]
    evals, evecs = jnp.linalg.eigh(H0)
    U0 = evecs @ jnp.diag(jnp.exp(-1j*dt*evals)) @ evecs.conj().T
    P1 = U0 @ P0 @ U0.conj().T
    propagated_dens.append( P1 )
    def bodyfun(i, dl):
        P0 = dl[i, :, :]
        P1 = dl[i+1, :, :]
        H1 = MLham(theta,(i+1.0)*dt,P1.real, P1.imag,[],fldfrq,fldamp,tmeoff,norm_direc)
        H1 = H1[0] + 1.0j*H1[1]
        evals, evecs = jnp.linalg.eigh(H1)
        U1 = evecs @ jnp.diag(jnp.exp(-2j*dt*evals)) @ evecs.conj().T
        P2 = U1 @ P0 @ U1.conj().T
        return dl.at[i+2].set( P2 )
    alldens = jnp.concatenate([jnp.stack(propagated_dens), jnp.zeros((ntvec-1, drc, drc))], axis=0) 
    fdl = lax.fori_loop(0, ntvec-1, bodyfun, alldens)
    
    return fdl

# %%
def preprocess_memory(theta, initial_density, amt_steps, dt=0.08268,
                  tmeoff=1, fldfrq=1, fldamp=1, norm_direc=jnp.array([0.0,0.0,1.0])):
    P0 = initial_density.reshape((drc, drc))
    propagated_dens = [P0]
    H0 = MLham(theta, 0.0, P0.real, P0.imag, [], fldfrq, fldamp, tmeoff, norm_direc)
    H0 = H0[0] + 1.0j*H0[1] 
    evals, evecs = jnp.linalg.eigh(H0)
    U0 = evecs @ jnp.diag(jnp.exp(-1j*dt*evals)) @ evecs.conj().T
    P1 = U0 @ P0 @ U0.conj().T
    propagated_dens.append( P1 )
    for k in range(0,amt_steps-1):
        P0 = propagated_dens[k]
        P1 = propagated_dens[k+1]
        H1 = MLham(theta, (k+1.0)*dt, P1.real, P1.imag, [], fldfrq, fldamp, tmeoff, norm_direc)
        H1 = H1[0] + 1.0j*H1[1] 
        evals, evecs = jnp.linalg.eigh(H1)
        U1 = evecs @ jnp.diag(jnp.exp(-2j*dt*evals)) @ evecs.conj().T
        P2 = U1 @ P0 @ U1.conj().T
        propagated_dens.append( P2 )
    return jnp.array(propagated_dens)

# %%
# # unit test to see if manual propagation preprocess code functions the same as previously working propagation code 
# i = 145
# mynumsteps = 500
# ic = trnden[i][0,:,:].reshape((-1))
# testtheta = 0.01 * jnp.array(np.random.normal(size=numparams))
# kernel = preprocess_memory(testtheta, ic, 100, dt=dt, tmeoff=trntme[i], fldfrq=trnfrq[i], fldamp=trnamp[i])
# true_prop  = MMUT_Prop_HSB(testtheta, ic, dt=dt, ntvec=mynumsteps,tmeoff=trntme[i], fldfrq=trnfrq[i], fldamp=trnamp[i])
# np.allclose(kernel,true_prop[:101,:,:],1e-10)

# %%
def MMUT_Prop_Memory(theta, initial_density, dt=0.08268, ntvec=2000,
                  tmeoff=1, fldfrq=1, fldamp=1, norm_direc=jnp.array([0.0,0.0,1.0])):
    memory_depth = 200
    propagated_dens = preprocess_memory(theta,initial_density, memory_depth, dt, tmeoff, fldfrq, fldamp ,norm_direc)
    def bodyfun(i, dl):
        P0 = dl[i, :, :]
        P1 = dl[i+1, :, :] 
        memory_kernel = [(dl[i-k, :, :].real, dl[i-k, :, :].imag) for k in range(memory_depth)]
        memory_kernel = memory_kernel[0::10]
        H1 = MLham(theta,(i+1.0)*dt,P1.real, P1.imag,memory_kernel, fldfrq,fldamp,tmeoff,norm_direc)
        H1 = H1[0] + 1.0j*H1[1]
        evals, evecs = jnp.linalg.eigh(H1)
        U1 = evecs @ jnp.diag(jnp.exp(-2j*dt*evals)) @ evecs.conj().T
        P2 = U1 @ P0 @ U1.conj().T
        return dl.at[i+2].set( P2 )
    alldens = jnp.concatenate([jnp.stack(propagated_dens), jnp.zeros((ntvec-(memory_depth), drc, drc))], axis=0) 
    fdl = lax.fori_loop(memory_depth-1, ntvec-1, bodyfun, alldens)
    
    return fdl

# %%
# single-trajectory loss
def loss(theta, i):
    mlprop = MMUT_Prop_Memory(theta, ic, dt=dt, ntvec=mynumsteps,
                           tmeoff=trntme[i], fldfrq=trnfrq[i], fldamp=trnamp[i])
    resid = mlprop - trnden[i,:mynumsteps+1, :, :]
    sse = 0.5*jnp.real(jnp.mean(jnp.conj(resid)*resid))
    return sse

# %%
# gradient of single-trajectory loss
def gradloss(theta, i):
    return MMUT_Adjoint(theta, 
                        jnp.array(trnden[i,:mynumsteps+1,:,:]), dt=dt, 
                        tmeoff=trntme[i], fldfrq=trnfrq[i], fldamp=trnamp[i])

# %%
# # # this is a sanity check

# # the single-trajectory loss evaluated at the *true* theta should be super close to 0
# print( loss(thetatrue, 0))

# # the norm of the gradient of the single-trajectory loss at the *true* theta should be super close to 0
# print( jnp.linalg.norm( jnp.abs( gradloss(thetatrue, 0) ) ))

# %%
# # uncomment this cell to test whether the adjoint method's gradient agrees with JAX's gradient
# # you should get agreement to 6-7 decimal places --- j
i = 140
ic = trnden[i][0,:,:].reshape((-1))
print('propagating trajectory: {}'.format(i))
# Out:
# propagating trajectory: 140

# %%
from jax import grad, jacobian
jaxgradloss = grad(loss)
#thetarand = jnp.array(np.random.normal(size=32))
#thetarand = jnp.array(np.random.normal(size=2 * drc**2 + 2 * 2 * drc**4))
thetarand = 0.01 * jnp.array(np.random.normal(size=numparams))

# %%
# # #uncomment if you want a finite difference differentiation of the loss wrt theta
# perturbedtheta = np.copy(thetarand)
# fdtot = []
# for ind in trange(perturbedtheta.shape[0]):
#     perturbedtheta[ind] += 1e-6
#     losstheta = loss(thetarand,i)
#     lossperturbedtheta = loss(perturbedtheta,i)
#     fd = (lossperturbedtheta - losstheta)/1e-6
#     fdtot.append(fd)
#     perturbedtheta[ind] -= 1e-6
# fdtot = np.array(fdtot)

# %%
autodiffresult = jaxgradloss(thetarand, i)
#adjointresult = gradloss(thetarand, i)
#print(autodiffresult)
#print(adjointresult)
#print(jnp.mean(jnp.abs(autodiffresult-adjointresult)))

# %%
# print(jnp.mean(jnp.abs(autodiffresult-fdtot)))

# %%
# multi-trajectory loss
vloss = vmap(loss, (None,0))
jvloss = jit(vloss)

# gradient of multi-trajectory loss
vgradloss = vmap(jaxgradloss, (None, 0))
jvgradloss = jit(vgradloss)

# %%
# NumPy wrappers to our JAX functions for use with SciPy optimizers
#was arange(140,160)
def siobj(x):
    jx = jnp.array(x)
    return jnp.mean(jvloss( jx, jnp.arange(0,len(inds)))).item()

def sigrad(x):
    jx = jnp.array(x)
    return np.asarray( jnp.mean( jvgradloss( jx, jnp.arange(0,len(inds) )), axis=0 ), dtype = np.float64 )

# %%
# many-theta version of the loss function
vthetaloss = vmap(loss, (0, None))
jvthetaloss = jit(vthetaloss)

# %%
# evaluate the loss for many randomly sampled thetas
numruns = 300
np.random.seed(5)
manytheta0 = 1e-1*jnp.array(np.random.normal(size=numparams*numruns), dtype=np.float64).reshape((numruns, -1))

# use the many-theta version of the loss function,
# but only evaluate along one trajectory, to save memory and time
testloss = jvthetaloss(manytheta0, 0)

# plot log_{10} of the losses obtained from the random thetas
plt.plot(jnp.log(testloss)/jnp.log(10))
plt.show()

# pick the best theta
minind = jnp.argmin(testloss)
theta0 = manytheta0[minind]

# %%
lr = 1e-2
theta = np.copy(trainedtheta)
maxiters = 10000
ic = trnden[0][0,:,:].reshape((-1))
preds = []
for j in trange(maxiters):
    thisgrad = np.mean( jvgradloss( theta, jnp.arange(0,len(inds) )), axis=0 )
    theta -= lr*thisgrad
    myloss = jnp.mean(jvloss( theta, jnp.arange(0,len(inds)))).item()
    if j % 100 == 0:
        pred = MMUT_Prop_HSB(theta, ic, dt, ntvec=mynumsteps,
                  tmeoff=trntme[0], fldfrq=trnfrq[0], fldamp=trnamp[0], norm_direc=jnp.array([0.0,0.0,1.0]))
        preds.append(pred)
        
        print([j, myloss, np.linalg.norm(thisgrad)])
    lr *= 0.95
# Out:
#   0%|          | 1/10000 [00:01<3:55:52,  1.42s/it]
# [0, 0.001211151517649043, 6.214786913890609e-07]
#   1%|          | 101/10000 [01:36<2:57:44,  1.08s/it]
# [100, 0.0012141384531244356, 0.006510237132233972]
#   2%|▏         | 201/10000 [03:12<2:57:17,  1.09s/it]
# [200, 0.001214091478462908, 0.006454606112075816]
#   3%|▎         | 301/10000 [04:47<2:54:58,  1.08s/it]
# [300, 0.0012140912026515314, 0.006454278274669546]
#   4%|▍         | 401/10000 [06:23<2:53:52,  1.09s/it]
# [400, 0.0012140912010185658, 0.006454276333741554]
#   5%|▌         | 501/10000 [07:59<2:52:17,  1.09s/it]
# [500, 0.0012140912010089341, 0.006454276322305441]
#   6%|▌         | 601/10000 [09:35<2:51:01,  1.09s/it]
# [600, 0.0012140912010089593, 0.006454276322233083]
#   6%|▋         | 634/10000 [10:07<2:29:39,  1.04it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 7
#       5 preds = []
#       6 for j in trange(maxiters):
# ----> 7     thisgrad = np.mean( jvgradloss( theta, jnp.arange(0,len(inds) )), axis=0 )
#       8     theta -= lr*thisgrad
#       9     myloss = jnp.mean(jvloss( theta, jnp.arange(0,len(inds)))).item()
#
# KeyboardInterrupt:

# %%
# optimize using SciPy plus wrapped functions above (siobj & sigrad),
# starting from the initial theta0 chosen via random sampling
res = scipy.optimize.minimize( siobj, 
                               x0 = trainedtheta,
                               method = 'trust-constr', 
                               jac = sigrad,
                               options = {'disp': True, 'verbose': 2, 'xtol': 1e-10, 'gtol': 1e-10, 'maxiter': 1000} )
trainedtheta = res.x
# Out:
# | niter |f evals|CG iter|  obj func   |tr radius |   opt    |  c viol  |
# |-------|-------|-------|-------------|----------|----------|----------|
# |   1   |   1   |   0   | +1.2125e-03 | 1.00e+00 | 6.77e-08 | 0.00e+00 |
# |   2   |   2   |   1   | +1.2125e-03 | 1.00e+00 | 1.97e-07 | 0.00e+00 |
# |   3   |   3   |   3   | +1.2125e-03 | 1.00e+00 | 2.45e-07 | 0.00e+00 |
# |   4   |   4   |   4   | +1.2125e-03 | 1.00e+00 | 1.14e-07 | 0.00e+00 |
# |   5   |   5   |   7   | +1.2125e-03 | 1.00e+00 | 1.90e-07 | 0.00e+00 |
# |   6   |   6   |   9   | +1.2125e-03 | 1.00e+00 | 1.98e-07 | 0.00e+00 |
# |   7   |   7   |  11   | +1.2125e-03 | 1.00e+00 | 7.32e-08 | 0.00e+00 |
# |   8   |   8   |  15   | +1.2125e-03 | 1.00e+00 | 1.89e-07 | 0.00e+00 |
# |   9   |   9   |  16   | +1.2125e-03 | 1.00e+00 | 1.07e-07 | 0.00e+00 |
# |  10   |  10   |  18   | +1.2125e-03 | 1.00e+00 | 1.24e-07 | 0.00e+00 |
# |  11   |  11   |  20   | +1.2125e-03 | 1.00e+00 | 2.22e-07 | 0.00e+00 |
# |  100  |  100  |  475  | +1.2125e-03 | 1.15e+00 | 4.21e-07 | 0.00e+00 |
# |  101  |  101  |  487  | +1.2125e-03 | 1.15e+00 | 6.16e-07 | 0.00e+00 |
# |  102  |  102  |  489  | +1.2125e-03 | 1.15e+00 | 1.38e-07 | 0.00e+00 |
# |  103  |  103  |  508  | +1.2124e-03 | 1.15e+00 | 1.93e-07 | 0.00e+00 |
# |  104  |  104  |  511  | +1.2124e-03 | 1.15e+00 | 1.97e-07 | 0.00e+00 |
# |  105  |  105  |  513  | +1.2124e-03 | 1.15e+00 | 1.91e-07 | 0.00e+00 |
# |  106  |  106  |  516  | +1.2124e-03 | 1.15e+00 | 7.14e-07 | 0.00e+00 |
# |  107  |  107  |  517  | +1.2124e-03 | 1.15e+00 | 4.88e-07 | 0.00e+00 |
# |  108  |  108  |  518  | +1.2124e-03 | 1.15e+00 | 2.09e-07 | 0.00e+00 |
# |  109  |  109  |  522  | +1.2124e-03 | 1.15e+00 | 2.52e-07 | 0.00e+00 |
# |  110  |  110  |  530  | +1.2124e-03 | 1.15e+00 | 2.46e-06 | 0.00e+00 |
# |  111  |  111  |  531  | +1.2124e-03 | 1.15e+00 | 1.07e-06 | 0.00e+00 |
# |  112  |  112  |  536  | +1.2124e-03 | 1.15e+00 | 1.58e-07 | 0.00e+00 |
# |  113  |  113  |  548  | +1.2124e-03 | 1.15e+00 | 1.39e-06 | 0.00e+00 |
# |  114  |  114  |  550  | +1.2124e-03 | 1.15e+00 | 2.23e-07 | 0.00e+00 |
# |  115  |  115  |  563  | +1.2124e-03 | 1.15e+00 | 2.00e-07 | 0.00e+00 |
# |  116  |  116  |  575  | +1.2124e-03 | 1.15e+00 | 1.79e-07 | 0.00e+00 |
# |  117  |  117  |  585  | +1.2124e-03 | 1.15e+00 | 1.11e-07 | 0.00e+00 |
# |  118  |  118  |  613  | +1.2124e-03 | 1.15e+00 | 3.68e-06 | 0.00e+00 |
# |  119  |  119  |  614  | +1.2124e-03 | 1.15e+00 | 9.51e-07 | 0.00e+00 |
# |  120  |  120  |  616  | +1.2124e-03 | 1.15e+00 | 2.31e-07 | 0.00e+00 |
# |  121  |  121  |  623  | +1.2124e-03 | 1.15e+00 | 1.61e-07 | 0.00e+00 |
# |  122  |  122  |  624  | +1.2124e-03 | 1.15e+00 | 1.63e-07 | 0.00e+00 |
# |  123  |  123  |  627  | +1.2124e-03 | 1.15e+00 | 1.26e-06 | 0.00e+00 |
# |  124  |  124  |  628  | +1.2124e-03 | 1.15e+00 | 7.44e-07 | 0.00e+00 |
# |  125  |  125  |  630  | +1.2124e-03 | 1.15e+00 | 3.07e-07 | 0.00e+00 |
# |  126  |  126  |  638  | +1.2124e-03 | 1.15e+00 | 2.06e-06 | 0.00e+00 |
# |  127  |  127  |  639  | +1.2124e-03 | 1.15e+00 | 9.12e-07 | 0.00e+00 |
# |  128  |  128  |  640  | +1.2124e-03 | 1.15e+00 | 1.95e-07 | 0.00e+00 |
# |  129  |  129  |  649  | +1.2124e-03 | 1.15e+00 | 7.22e-07 | 0.00e+00 |
# |  130  |  130  |  653  | +1.2124e-03 | 1.15e+00 | 2.24e-07 | 0.00e+00 |
# |  131  |  131  |  670  | +1.2124e-03 | 1.15e+00 | 5.51e-07 | 0.00e+00 |
# |  132  |  132  |  675  | +1.2124e-03 | 1.15e+00 | 1.78e-07 | 0.00e+00 |
# |  133  |  133  |  695  | +1.2124e-03 | 1.15e+00 | 1.78e-07 | 0.00e+00 |
# |  134  |  134  |  707  | +1.2124e-03 | 1.15e+00 | 1.59e-07 | 0.00e+00 |
# |  135  |  135  |  730  | +1.2124e-03 | 1.15e+00 | 2.06e-07 | 0.00e+00 |
# |  136  |  136  |  733  | +1.2124e-03 | 1.15e+00 | 1.01e-07 | 0.00e+00 |
# |  137  |  137  |  769  | +1.2124e-03 | 1.15e+00 | 1.36e-06 | 0.00e+00 |
# |  138  |  138  |  771  | +1.2124e-03 | 1.15e+00 | 3.47e-07 | 0.00e+00 |
# |  139  |  139  |  776  | +1.2124e-03 | 1.15e+00 | 1.35e-07 | 0.00e+00 |
# |  140  |  140  |  785  | +1.2124e-03 | 1.15e+00 | 2.77e-07 | 0.00e+00 |
# |  141  |  141  |  786  | +1.2124e-03 | 1.15e+00 | 1.40e-07 | 0.00e+00 |
# |  142  |  142  |  799  | +1.2124e-03 | 1.15e+00 | 1.24e-07 | 0.00e+00 |
# |  143  |  143  |  801  | +1.2124e-03 | 1.15e+00 | 1.24e-07 | 0.00e+00 |
# |  144  |  144  |  805  | +1.2124e-03 | 1.15e+00 | 9.59e-07 | 0.00e+00 |
# |  145  |  145  |  806  | +1.2124e-03 | 1.15e+00 | 5.98e-07 | 0.00e+00 |
# |  146  |  146  |  807  | +1.2124e-03 | 1.15e+00 | 2.11e-07 | 0.00e+00 |
# |  147  |  147  |  812  | +1.2124e-03 | 1.15e+00 | 3.42e-07 | 0.00e+00 |
# |  148  |  148  |  814  | +1.2124e-03 | 1.15e+00 | 2.32e-07 | 0.00e+00 |
# |  149  |  149  |  822  | +1.2124e-03 | 1.15e+00 | 1.23e-06 | 0.00e+00 |
# |  150  |  150  |  824  | +1.2124e-03 | 1.15e+00 | 4.71e-07 | 0.00e+00 |
# |  151  |  151  |  826  | +1.2124e-03 | 1.15e+00 | 1.12e-07 | 0.00e+00 |
# |  152  |  152  |  846  | +1.2124e-03 | 1.15e+00 | 9.87e-07 | 0.00e+00 |
# |  153  |  153  |  850  | +1.2124e-03 | 1.15e+00 | 2.96e-07 | 0.00e+00 |
# |  154  |  154  |  862  | +1.2124e-03 | 1.15e+00 | 2.04e-07 | 0.00e+00 |
# |  155  |  155  |  887  | +1.2124e-03 | 1.15e+00 | 1.22e-06 | 0.00e+00 |
# |  156  |  156  |  889  | +1.2124e-03 | 1.15e+00 | 1.80e-07 | 0.00e+00 |
# |  157  |  157  |  928  | +1.2123e-03 | 3.58e+00 | 4.78e-06 | 0.00e+00 |
# |  158  |  158  |  929  | +1.2123e-03 | 3.58e+00 | 1.39e-06 | 0.00e+00 |
# |  159  |  159  |  934  | +1.2123e-03 | 3.58e+00 | 7.79e-07 | 0.00e+00 |
# |  160  |  160  |  944  | +1.2123e-03 | 3.58e+00 | 1.69e-06 | 0.00e+00 |
# |  161  |  161  |  946  | +1.2123e-03 | 3.58e+00 | 5.21e-07 | 0.00e+00 |
# |  162  |  162  |  956  | +1.2123e-03 | 3.58e+00 | 1.06e-06 | 0.00e+00 |
# |  163  |  163  |  958  | +1.2123e-03 | 3.58e+00 | 2.60e-07 | 0.00e+00 |
# |  164  |  164  |  984  | +1.2122e-03 | 3.58e+00 | 6.45e-06 | 0.00e+00 |
# |  165  |  165  |  986  | +1.2122e-03 | 3.58e+00 | 3.62e-07 | 0.00e+00 |
# |  166  |  166  | 1001  | +1.2122e-03 | 3.58e+00 | 4.34e-07 | 0.00e+00 |
# |  167  |  167  | 1005  | +1.2122e-03 | 3.58e+00 | 8.43e-08 | 0.00e+00 |
# |  168  |  168  | 1050  | +1.2122e-03 | 3.58e+00 | 4.52e-05 | 0.00e+00 |
# |  169  |  169  | 1052  | +1.2121e-03 | 3.58e+00 | 7.07e-06 | 0.00e+00 |
# |  170  |  170  | 1054  | +1.2121e-03 | 3.58e+00 | 1.11e-05 | 0.00e+00 |
# |  171  |  171  | 1056  | +1.2121e-03 | 3.58e+00 | 1.62e-06 | 0.00e+00 |
# |  172  |  172  | 1070  | +1.2121e-03 | 3.58e+00 | 2.50e-05 | 0.00e+00 |
# |  173  |  173  | 1071  | +1.2121e-03 | 3.58e+00 | 6.30e-06 | 0.00e+00 |
# |  174  |  174  | 1073  | +1.2121e-03 | 3.58e+00 | 5.75e-07 | 0.00e+00 |
# |  175  |  175  | 1087  | +1.2121e-03 | 3.58e+00 | 4.99e-07 | 0.00e+00 |
# |  176  |  176  | 1094  | +1.2121e-03 | 3.58e+00 | 2.17e-07 | 0.00e+00 |
# |  177  |  177  | 1114  | +1.2121e-03 | 3.58e+00 | 4.99e-07 | 0.00e+00 |
# |  178  |  178  | 1120  | +1.2121e-03 | 3.58e+00 | 1.38e-07 | 0.00e+00 |
# |  179  |  179  | 1151  | +1.2121e-03 | 3.58e+00 | 3.18e-06 | 0.00e+00 |
# |  180  |  180  | 1153  | +1.2121e-03 | 3.58e+00 | 4.92e-07 | 0.00e+00 |
# |  181  |  181  | 1162  | +1.2121e-03 | 3.58e+00 | 3.92e-07 | 0.00e+00 |
# |  182  |  182  | 1173  | +1.2121e-03 | 3.58e+00 | 4.14e-07 | 0.00e+00 |
# |  183  |  183  | 1181  | +1.2121e-03 | 3.58e+00 | 2.61e-07 | 0.00e+00 |
# |  184  |  184  | 1190  | +1.2121e-03 | 3.58e+00 | 1.04e-07 | 0.00e+00 |
# |  185  |  185  | 1211  | +1.2121e-03 | 3.58e+00 | 9.51e-07 | 0.00e+00 |
# |  186  |  186  | 1212  | +1.2121e-03 | 3.58e+00 | 1.52e-07 | 0.00e+00 |
# |  187  |  187  | 1226  | +1.2121e-03 | 3.58e+00 | 1.03e-07 | 0.00e+00 |
# |  188  |  188  | 1235  | +1.2121e-03 | 3.58e+00 | 1.09e-07 | 0.00e+00 |
# |  189  |  189  | 1243  | +1.2121e-03 | 3.58e+00 | 1.20e-07 | 0.00e+00 |
# |  190  |  190  | 1251  | +1.2121e-03 | 3.58e+00 | 1.04e-07 | 0.00e+00 |
# |  191  |  191  | 1259  | +1.2121e-03 | 3.58e+00 | 1.11e-07 | 0.00e+00 |
# |  192  |  192  | 1264  | +1.2121e-03 | 3.58e+00 | 1.10e-07 | 0.00e+00 |
# |  193  |  193  | 1270  | +1.2121e-03 | 3.58e+00 | 1.10e-07 | 0.00e+00 |
# |  194  |  194  | 1272  | +1.2121e-03 | 3.58e+00 | 1.12e-07 | 0.00e+00 |
# |  195  |  195  | 1276  | +1.2121e-03 | 3.58e+00 | 8.65e-07 | 0.00e+00 |
# |  196  |  196  | 1277  | +1.2121e-03 | 3.58e+00 | 4.33e-07 | 0.00e+00 |
# |  197  |  197  | 1279  | +1.2121e-03 | 3.58e+00 | 1.34e-07 | 0.00e+00 |
# |  198  |  198  | 1286  | +1.2121e-03 | 3.58e+00 | 9.26e-07 | 0.00e+00 |
# |  199  |  199  | 1287  | +1.2121e-03 | 3.58e+00 | 4.86e-07 | 0.00e+00 |
# |  200  |  200  | 1289  | +1.2121e-03 | 3.58e+00 | 1.16e-07 | 0.00e+00 |
# |  201  |  201  | 1296  | +1.2121e-03 | 3.58e+00 | 1.31e-06 | 0.00e+00 |
# |  202  |  202  | 1297  | +1.2121e-03 | 3.58e+00 | 3.92e-07 | 0.00e+00 |
# |  203  |  203  | 1300  | +1.2121e-03 | 3.58e+00 | 1.80e-07 | 0.00e+00 |
# |  204  |  204  | 1316  | +1.2121e-03 | 3.58e+00 | 3.82e-06 | 0.00e+00 |
# |  205  |  205  | 1317  | +1.2121e-03 | 3.58e+00 | 9.16e-07 | 0.00e+00 |
# |  206  |  206  | 1319  | +1.2121e-03 | 3.58e+00 | 2.69e-07 | 0.00e+00 |
# |  207  |  207  | 1348  | +1.2121e-03 | 3.58e+00 | 3.14e-06 | 0.00e+00 |
# |  208  |  208  | 1350  | +1.2121e-03 | 3.58e+00 | 7.20e-07 | 0.00e+00 |
# |  209  |  209  | 1359  | +1.2121e-03 | 3.58e+00 | 1.33e-07 | 0.00e+00 |
# |  210  |  210  | 1378  | +1.2121e-03 | 3.58e+00 | 5.64e-07 | 0.00e+00 |
# |  211  |  211  | 1379  | +1.2121e-03 | 3.58e+00 | 1.34e-07 | 0.00e+00 |
# |  212  |  212  | 1412  | +1.2121e-03 | 3.58e+00 | 2.16e-06 | 0.00e+00 |
# |  213  |  213  | 1414  | +1.2121e-03 | 3.58e+00 | 5.84e-07 | 0.00e+00 |
# |  214  |  214  | 1421  | +1.2121e-03 | 3.58e+00 | 1.90e-07 | 0.00e+00 |
# |  215  |  215  | 1435  | +1.2121e-03 | 3.58e+00 | 1.17e-07 | 0.00e+00 |
# |  274  |  274  | 1996  | +1.2119e-03 | 3.58e+00 | 1.42e-07 | 0.00e+00 |
# |  275  |  275  | 2035  | +1.2119e-03 | 3.58e+00 | 9.10e-07 | 0.00e+00 |
# |  276  |  276  | 2037  | +1.2119e-03 | 3.58e+00 | 2.51e-07 | 0.00e+00 |
# |  277  |  277  | 2056  | +1.2119e-03 | 3.58e+00 | 1.83e-07 | 0.00e+00 |
# |  278  |  278  | 2066  | +1.2119e-03 | 3.58e+00 | 1.53e-07 | 0.00e+00 |
# |  279  |  279  | 2106  | +1.2119e-03 | 3.58e+00 | 2.61e-06 | 0.00e+00 |
# |  280  |  280  | 2107  | +1.2119e-03 | 3.58e+00 | 2.95e-07 | 0.00e+00 |
# |  281  |  281  | 2109  | +1.2119e-03 | 3.58e+00 | 1.16e-07 | 0.00e+00 |
# |  282  |  282  | 2137  | +1.2119e-03 | 3.58e+00 | 7.24e-07 | 0.00e+00 |
# |  283  |  283  | 2140  | +1.2119e-03 | 3.58e+00 | 1.55e-07 | 0.00e+00 |
# |  284  |  284  | 2151  | +1.2119e-03 | 3.58e+00 | 1.13e-07 | 0.00e+00 |
# |  285  |  285  | 2180  | +1.2119e-03 | 3.58e+00 | 1.10e-07 | 0.00e+00 |
# |  286  |  286  | 2208  | +1.2119e-03 | 3.58e+00 | 8.43e-08 | 0.00e+00 |
# |  287  |  287  | 2260  | +1.2119e-03 | 3.58e+00 | 1.02e-05 | 0.00e+00 |
# |  288  |  288  | 2264  | +1.2119e-03 | 3.58e+00 | 1.55e-06 | 0.00e+00 |
# |  289  |  289  | 2275  | +1.2118e-03 | 3.58e+00 | 1.44e-06 | 0.00e+00 |
# |  290  |  290  | 2282  | +1.2118e-03 | 3.58e+00 | 6.30e-06 | 0.00e+00 |
# |  291  |  291  | 2283  | +1.2118e-03 | 3.58e+00 | 7.44e-07 | 0.00e+00 |
# |  292  |  292  | 2292  | +1.2118e-03 | 3.58e+00 | 3.53e-07 | 0.00e+00 |
# |  293  |  293  | 2303  | +1.2118e-03 | 3.58e+00 | 2.63e-07 | 0.00e+00 |
# |  294  |  294  | 2319  | +1.2118e-03 | 3.58e+00 | 3.65e-07 | 0.00e+00 |
# |  295  |  295  | 2324  | +1.2118e-03 | 3.58e+00 | 6.38e-08 | 0.00e+00 |
# |  296  |  296  | 2374  | +1.2118e-03 | 3.58e+00 | 1.40e-06 | 0.00e+00 |
# |  297  |  297  | 2377  | +1.2118e-03 | 3.58e+00 | 8.33e-07 | 0.00e+00 |
# |  298  |  298  | 2378  | +1.2118e-03 | 3.58e+00 | 2.02e-07 | 0.00e+00 |
# |  299  |  299  | 2390  | +1.2118e-03 | 3.58e+00 | 8.90e-08 | 0.00e+00 |
# |  300  |  300  | 2423  | +1.2118e-03 | 3.58e+00 | 1.36e-06 | 0.00e+00 |
# |  301  |  301  | 2424  | +1.2118e-03 | 3.58e+00 | 2.04e-07 | 0.00e+00 |
# |  302  |  302  | 2436  | +1.2118e-03 | 3.58e+00 | 2.08e-07 | 0.00e+00 |
# |  303  |  303  | 2448  | +1.2118e-03 | 3.58e+00 | 3.57e-08 | 0.00e+00 |
# |  304  |  304  | 2522  | +1.2118e-03 | 3.94e+00 | 3.79e-06 | 0.00e+00 |
# |  305  |  305  | 2529  | +1.2118e-03 | 3.94e+00 | 1.68e-06 | 0.00e+00 |
# |  306  |  306  | 2534  | +1.2118e-03 | 3.94e+00 | 4.73e-07 | 0.00e+00 |
# |  307  |  307  | 2545  | +1.2118e-03 | 3.94e+00 | 7.85e-07 | 0.00e+00 |
# |  308  |  308  | 2553  | +1.2118e-03 | 3.94e+00 | 2.33e-07 | 0.00e+00 |
# |  309  |  309  | 2569  | +1.2118e-03 | 3.94e+00 | 3.54e-07 | 0.00e+00 |
# |  310  |  310  | 2570  | +1.2118e-03 | 3.94e+00 | 9.21e-08 | 0.00e+00 |
# |  311  |  311  | 2589  | +1.2118e-03 | 3.94e+00 | 1.44e-07 | 0.00e+00 |
# |  312  |  312  | 2595  | +1.2118e-03 | 3.94e+00 | 8.11e-08 | 0.00e+00 |
# |  313  |  313  | 2600  | +1.2118e-03 | 3.94e+00 | 4.31e-08 | 0.00e+00 |
# |  314  |  314  | 2619  | +1.2118e-03 | 3.94e+00 | 6.99e-08 | 0.00e+00 |
# |  315  |  315  | 2622  | +1.2118e-03 | 3.94e+00 | 2.15e-08 | 0.00e+00 |
# |  316  |  316  | 2655  | +1.2118e-03 | 3.94e+00 | 1.01e-06 | 0.00e+00 |
# |  317  |  317  | 2656  | +1.2118e-03 | 3.94e+00 | 1.08e-07 | 0.00e+00 |
# |  318  |  318  | 2660  | +1.2118e-03 | 3.94e+00 | 3.76e-08 | 0.00e+00 |
# |  319  |  319  | 2670  | +1.2118e-03 | 3.94e+00 | 1.77e-08 | 0.00e+00 |
# |  320  |  320  | 2720  | +1.2118e-03 | 3.94e+00 | 1.67e-07 | 0.00e+00 |
# |  321  |  321  | 2730  | +1.2118e-03 | 3.94e+00 | 2.51e-08 | 0.00e+00 |
# |  322  |  322  | 2745  | +1.2118e-03 | 3.94e+00 | 4.00e-08 | 0.00e+00 |
# |  323  |  323  | 2757  | +1.2118e-03 | 3.94e+00 | 1.99e-08 | 0.00e+00 |
# |  324  |  324  | 2784  | +1.2118e-03 | 3.94e+00 | 2.36e-07 | 0.00e+00 |
# |  325  |  325  | 2785  | +1.2118e-03 | 3.94e+00 | 3.44e-08 | 0.00e+00 |
# |  326  |  326  | 2789  | +1.2118e-03 | 3.94e+00 | 2.21e-08 | 0.00e+00 |
# |  327  |  327  | 2809  | +1.2118e-03 | 3.94e+00 | 1.86e-08 | 0.00e+00 |
# |  328  |  328  | 2829  | +1.2118e-03 | 3.94e+00 | 2.20e-08 | 0.00e+00 |
# |  329  |  329  | 2846  | +1.2118e-03 | 3.94e+00 | 2.05e-08 | 0.00e+00 |
# |  330  |  330  | 2863  | +1.2118e-03 | 3.94e+00 | 1.83e-08 | 0.00e+00 |
# |  331  |  331  | 2878  | +1.2118e-03 | 3.94e+00 | 1.78e-08 | 0.00e+00 |
# |  476  |  476  | 4683  | +1.2115e-03 | 4.82e+00 | 9.22e-07 | 0.00e+00 |
# |  477  |  477  | 4686  | +1.2115e-03 | 4.82e+00 | 2.00e-07 | 0.00e+00 |
# |  478  |  478  | 4696  | +1.2115e-03 | 4.82e+00 | 7.16e-08 | 0.00e+00 |
# |  479  |  479  | 4731  | +1.2115e-03 | 4.82e+00 | 3.94e-06 | 0.00e+00 |
# |  480  |  480  | 4734  | +1.2115e-03 | 4.82e+00 | 3.07e-06 | 0.00e+00 |
# |  481  |  481  | 4735  | +1.2115e-03 | 4.82e+00 | 1.28e-06 | 0.00e+00 |
# |  482  |  482  | 4743  | +1.2115e-03 | 4.82e+00 | 1.66e-07 | 0.00e+00 |
# |  483  |  483  | 4759  | +1.2115e-03 | 4.82e+00 | 3.18e-07 | 0.00e+00 |
# |  484  |  484  | 4763  | +1.2115e-03 | 4.82e+00 | 9.19e-08 | 0.00e+00 |
# |  485  |  485  | 4782  | +1.2115e-03 | 4.82e+00 | 2.22e-07 | 0.00e+00 |
# |  486  |  486  | 4792  | +1.2115e-03 | 4.82e+00 | 5.79e-08 | 0.00e+00 |
# |  487  |  487  | 4845  | +1.2115e-03 | 4.82e+00 | 2.75e-05 | 0.00e+00 |
# |  488  |  488  | 4848  | +1.2115e-03 | 4.82e+00 | 1.67e-05 | 0.00e+00 |
# |  489  |  489  | 4851  | +1.2114e-03 | 4.82e+00 | 6.33e-06 | 0.00e+00 |
# |  490  |  490  | 4854  | +1.2114e-03 | 4.82e+00 | 1.43e-06 | 0.00e+00 |
# |  491  |  491  | 4861  | +1.2114e-03 | 4.82e+00 | 1.52e-06 | 0.00e+00 |
# |  492  |  492  | 4862  | +1.2114e-03 | 4.82e+00 | 6.38e-07 | 0.00e+00 |
# |  493  |  493  | 4872  | +1.2114e-03 | 4.82e+00 | 2.44e-07 | 0.00e+00 |
# |  494  |  494  | 4881  | +1.2114e-03 | 4.82e+00 | 1.11e-07 | 0.00e+00 |
# |  495  |  495  | 4908  | +1.2114e-03 | 4.82e+00 | 1.49e-06 | 0.00e+00 |
# |  496  |  496  | 4911  | +1.2114e-03 | 4.82e+00 | 3.55e-07 | 0.00e+00 |
# |  497  |  497  | 4919  | +1.2114e-03 | 4.82e+00 | 6.86e-08 | 0.00e+00 |
# |  498  |  498  | 4926  | +1.2114e-03 | 4.82e+00 | 3.54e-08 | 0.00e+00 |
# |  499  |  499  | 5016  | +1.2114e-03 | 4.82e+00 | 7.18e-06 | 0.00e+00 |
# |  500  |  500  | 5017  | +1.2114e-03 | 4.82e+00 | 1.91e-06 | 0.00e+00 |
# |  501  |  501  | 5021  | +1.2114e-03 | 4.82e+00 | 5.64e-07 | 0.00e+00 |
# |  502  |  502  | 5029  | +1.2114e-03 | 4.82e+00 | 2.28e-07 | 0.00e+00 |
# |  503  |  503  | 5042  | +1.2114e-03 | 4.82e+00 | 5.82e-08 | 0.00e+00 |
# |  504  |  504  | 5083  | +1.2114e-03 | 4.82e+00 | 3.27e-06 | 0.00e+00 |
# |  505  |  505  | 5088  | +1.2114e-03 | 4.82e+00 | 6.06e-07 | 0.00e+00 |
# |  506  |  506  | 5095  | +1.2114e-03 | 4.82e+00 | 6.35e-07 | 0.00e+00 |
# |  507  |  507  | 5100  | +1.2114e-03 | 4.82e+00 | 1.96e-07 | 0.00e+00 |
# |  508  |  508  | 5104  | +1.2114e-03 | 4.82e+00 | 5.44e-08 | 0.00e+00 |
# |  509  |  509  | 5123  | +1.2114e-03 | 4.82e+00 | 2.11e-07 | 0.00e+00 |
# |  510  |  510  | 5126  | +1.2114e-03 | 4.82e+00 | 3.97e-08 | 0.00e+00 |
# |  511  |  511  | 5168  | +1.2114e-03 | 4.82e+00 | 4.02e-06 | 0.00e+00 |
# |  512  |  512  | 5171  | +1.2114e-03 | 4.82e+00 | 7.18e-07 | 0.00e+00 |
# |  513  |  513  | 5177  | +1.2114e-03 | 4.82e+00 | 1.72e-07 | 0.00e+00 |
# |  514  |  514  | 5186  | +1.2114e-03 | 4.82e+00 | 1.30e-07 | 0.00e+00 |
# |  515  |  515  | 5195  | +1.2114e-03 | 4.82e+00 | 5.99e-08 | 0.00e+00 |
# |  516  |  516  | 5214  | +1.2114e-03 | 4.82e+00 | 7.58e-07 | 0.00e+00 |
# |  517  |  517  | 5216  | +1.2114e-03 | 4.82e+00 | 1.13e-07 | 0.00e+00 |
# |  518  |  518  | 5219  | +1.2114e-03 | 4.82e+00 | 3.99e-08 | 0.00e+00 |
# |  519  |  519  | 5348  | +1.2114e-03 | 4.82e-01 | 3.99e-08 | 0.00e+00 |
# |  520  |  520  | 5418  | +1.2114e-03 | 9.63e-01 | 1.09e-05 | 0.00e+00 |
# |  521  |  521  | 5422  | +1.2114e-03 | 9.63e-01 | 8.45e-06 | 0.00e+00 |
# |  522  |  522  | 5425  | +1.2114e-03 | 9.63e-01 | 2.88e-06 | 0.00e+00 |
# |  523  |  523  | 5432  | +1.2114e-03 | 9.63e-01 | 1.81e-06 | 0.00e+00 |
# |  524  |  524  | 5435  | +1.2114e-03 | 9.63e-01 | 1.82e-07 | 0.00e+00 |
# |  525  |  525  | 5447  | +1.2114e-03 | 9.63e-01 | 5.81e-07 | 0.00e+00 |
# |  526  |  526  | 5448  | +1.2114e-03 | 9.63e-01 | 1.16e-07 | 0.00e+00 |
# |  527  |  527  | 5467  | +1.2114e-03 | 9.63e-01 | 2.78e-07 | 0.00e+00 |
# |  528  |  528  | 5472  | +1.2114e-03 | 9.63e-01 | 4.06e-08 | 0.00e+00 |
# |  529  |  529  | 5516  | +1.2114e-03 | 9.63e-01 | 2.35e-06 | 0.00e+00 |
# |  530  |  530  | 5519  | +1.2114e-03 | 9.63e-01 | 6.22e-07 | 0.00e+00 |
# |  531  |  531  | 5528  | +1.2114e-03 | 9.63e-01 | 3.76e-07 | 0.00e+00 |
# |  532  |  532  | 5541  | +1.2114e-03 | 9.63e-01 | 1.47e-07 | 0.00e+00 |
# |  533  |  533  | 5558  | +1.2114e-03 | 9.63e-01 | 5.22e-07 | 0.00e+00 |
# |  534  |  534  | 5561  | +1.2114e-03 | 9.63e-01 | 8.35e-08 | 0.00e+00 |
# |  535  |  535  | 5580  | +1.2114e-03 | 9.63e-01 | 4.64e-08 | 0.00e+00 |
# |  536  |  536  | 5609  | +1.2114e-03 | 9.63e-01 | 1.31e-07 | 0.00e+00 |
# |  537  |  537  | 5614  | +1.2114e-03 | 9.63e-01 | 2.67e-08 | 0.00e+00 |
# |  538  |  538  | 5647  | +1.2114e-03 | 9.63e-01 | 5.32e-07 | 0.00e+00 |
# |  539  |  539  | 5648  | +1.2114e-03 | 9.63e-01 | 1.04e-07 | 0.00e+00 |
# |  540  |  540  | 5653  | +1.2114e-03 | 9.63e-01 | 3.91e-08 | 0.00e+00 |
# |  541  |  541  | 5734  | +1.2114e-03 | 6.74e+00 | 1.79e-05 | 0.00e+00 |
# |  542  |  542  | 5737  | +1.2114e-03 | 6.74e+00 | 5.94e-06 | 0.00e+00 |
# |  543  |  543  | 5740  | +1.2114e-03 | 6.74e+00 | 1.15e-06 | 0.00e+00 |
# |  544  |  544  | 5749  | +1.2114e-03 | 6.74e+00 | 3.82e-06 | 0.00e+00 |
# |  545  |  545  | 5750  | +1.2114e-03 | 6.74e+00 | 1.34e-06 | 0.00e+00 |
# |  546  |  546  | 5751  | +1.2114e-03 | 6.74e+00 | 3.50e-07 | 0.00e+00 |
# |  547  |  547  | 5762  | +1.2114e-03 | 6.74e+00 | 7.62e-07 | 0.00e+00 |
# |  548  |  548  | 5765  | +1.2114e-03 | 6.74e+00 | 4.19e-07 | 0.00e+00 |
# |  549  |  549  | 5770  | +1.2114e-03 | 6.74e+00 | 9.83e-08 | 0.00e+00 |
# |  550  |  550  | 5799  | +1.2114e-03 | 6.74e+00 | 1.11e-06 | 0.00e+00 |
# |  551  |  551  | 5806  | +1.2114e-03 | 6.74e+00 | 9.55e-07 | 0.00e+00 |
# |  552  |  552  | 5813  | +1.2114e-03 | 6.74e+00 | 1.87e-07 | 0.00e+00 |
# |  553  |  553  | 5830  | +1.2114e-03 | 6.74e+00 | 7.87e-07 | 0.00e+00 |
# |  554  |  554  | 5833  | +1.2114e-03 | 6.74e+00 | 1.05e-07 | 0.00e+00 |
# |  555  |  555  | 5842  | +1.2114e-03 | 6.74e+00 | 5.43e-08 | 0.00e+00 |
# |  556  |  556  | 5870  | +1.2114e-03 | 6.74e+00 | 7.95e-07 | 0.00e+00 |
# |  557  |  557  | 5876  | +1.2114e-03 | 6.74e+00 | 1.54e-07 | 0.00e+00 |
# |  558  |  558  | 5887  | +1.2114e-03 | 6.74e+00 | 8.49e-08 | 0.00e+00 |
# |  559  |  559  | 5890  | +1.2114e-03 | 6.74e+00 | 2.42e-08 | 0.00e+00 |
# |  560  |  560  | 5927  | +1.2114e-03 | 6.74e+00 | 6.00e-07 | 0.00e+00 |
# |  561  |  561  | 5930  | +1.2114e-03 | 6.74e+00 | 6.76e-08 | 0.00e+00 |
# |  562  |  562  | 5935  | +1.2114e-03 | 6.74e+00 | 1.88e-08 | 0.00e+00 |
# |  563  |  563  | 5980  | +1.2114e-03 | 6.74e+00 | 1.67e-06 | 0.00e+00 |
# |  564  |  564  | 5983  | +1.2114e-03 | 6.74e+00 | 8.62e-08 | 0.00e+00 |
# |  565  |  565  | 5986  | +1.2114e-03 | 6.74e+00 | 1.94e-08 | 0.00e+00 |
# |  566  |  566  | 6006  | +1.2114e-03 | 6.74e+00 | 1.86e-08 | 0.00e+00 |
# |  567  |  567  | 6056  | +1.2114e-03 | 6.74e+00 | 3.18e-06 | 0.00e+00 |
# |  568  |  568  | 6058  | +1.2114e-03 | 6.74e+00 | 9.21e-07 | 0.00e+00 |
# |  569  |  569  | 6060  | +1.2114e-03 | 6.74e+00 | 2.13e-07 | 0.00e+00 |
# |  570  |  570  | 6065  | +1.2114e-03 | 6.74e+00 | 4.32e-08 | 0.00e+00 |
# |  571  |  571  | 6072  | +1.2114e-03 | 6.74e+00 | 1.93e-08 | 0.00e+00 |
# |  572  |  572  | 6102  | +1.2114e-03 | 6.74e+00 | 1.47e-07 | 0.00e+00 |
# |  573  |  573  | 6105  | +1.2114e-03 | 6.74e+00 | 2.11e-08 | 0.00e+00 |
# |  574  |  574  | 6119  | +1.2114e-03 | 6.74e+00 | 3.09e-08 | 0.00e+00 |
# |  575  |  575  | 6133  | +1.2114e-03 | 6.74e+00 | 2.38e-08 | 0.00e+00 |
# |  576  |  576  | 6156  | +1.2114e-03 | 6.74e+00 | 1.64e-07 | 0.00e+00 |
# |  577  |  577  | 6159  | +1.2114e-03 | 6.74e+00 | 3.24e-08 | 0.00e+00 |
# |  578  |  578  | 6166  | +1.2114e-03 | 6.74e+00 | 1.25e-08 | 0.00e+00 |
# |  579  |  579  | 6186  | +1.2114e-03 | 6.74e+00 | 1.68e-08 | 0.00e+00 |
# |  580  |  580  | 6206  | +1.2114e-03 | 6.74e+00 | 3.82e-08 | 0.00e+00 |
# |  581  |  581  | 6207  | +1.2114e-03 | 6.74e+00 | 1.01e-08 | 0.00e+00 |
# |  582  |  582  | 6227  | +1.2114e-03 | 6.74e+00 | 9.46e-09 | 0.00e+00 |
# |  583  |  583  | 6247  | +1.2114e-03 | 6.74e+00 | 1.11e-08 | 0.00e+00 |
# |  584  |  584  | 6249  | +1.2114e-03 | 6.74e+00 | 1.02e-08 | 0.00e+00 |
# |  585  |  585  | 6269  | +1.2114e-03 | 6.74e+00 | 5.74e-08 | 0.00e+00 |
# |  586  |  586  | 6270  | +1.2114e-03 | 6.74e+00 | 2.70e-08 | 0.00e+00 |
# |  587  |  587  | 6277  | +1.2114e-03 | 6.74e+00 | 1.99e-08 | 0.00e+00 |
# |  588  |  588  | 6285  | +1.2114e-03 | 6.74e+00 | 3.42e-07 | 0.00e+00 |
# |  589  |  589  | 6286  | +1.2114e-03 | 6.74e+00 | 2.17e-07 | 0.00e+00 |
# |  590  |  590  | 6287  | +1.2114e-03 | 6.74e+00 | 3.79e-08 | 0.00e+00 |
# |  591  |  591  | 6299  | +1.2114e-03 | 6.74e+00 | 5.68e-08 | 0.00e+00 |
# |  592  |  592  | 6302  | +1.2114e-03 | 6.74e+00 | 2.06e-08 | 0.00e+00 |
# |  593  |  593  | 6321  | +1.2114e-03 | 6.74e+00 | 3.55e-07 | 0.00e+00 |
# |  594  |  594  | 6328  | +1.2114e-03 | 6.74e+00 | 1.33e-07 | 0.00e+00 |
# |  595  |  595  | 6335  | +1.2114e-03 | 6.74e+00 | 3.51e-08 | 0.00e+00 |
# |  596  |  596  | 6354  | +1.2114e-03 | 6.74e+00 | 7.50e-08 | 0.00e+00 |
# |  597  |  597  | 6368  | +1.2114e-03 | 6.74e+00 | 3.01e-08 | 0.00e+00 |
# |  598  |  598  | 6391  | +1.2114e-03 | 6.74e+00 | 3.48e-07 | 0.00e+00 |
# |  599  |  599  | 6398  | +1.2114e-03 | 6.74e+00 | 1.12e-07 | 0.00e+00 |
# |  600  |  600  | 6412  | +1.2114e-03 | 6.74e+00 | 1.97e-08 | 0.00e+00 |
# |  601  |  601  | 6458  | +1.2113e-03 | 6.74e+00 | 1.80e-05 | 0.00e+00 |
# |  602  |  602  | 6460  | +1.2113e-03 | 6.74e+00 | 4.56e-06 | 0.00e+00 |
# |  603  |  603  | 6463  | +1.2113e-03 | 6.74e+00 | 1.62e-06 | 0.00e+00 |
# |  604  |  604  | 6466  | +1.2113e-03 | 6.74e+00 | 4.09e-07 | 0.00e+00 |
# |  605  |  605  | 6483  | +1.2113e-03 | 6.74e+00 | 8.17e-07 | 0.00e+00 |
# |  606  |  606  | 6490  | +1.2113e-03 | 6.74e+00 | 2.27e-07 | 0.00e+00 |
# |  607  |  607  | 6509  | +1.2113e-03 | 6.74e+00 | 3.72e-07 | 0.00e+00 |
# |  608  |  608  | 6512  | +1.2113e-03 | 6.74e+00 | 3.80e-08 | 0.00e+00 |
# |  609  |  609  | 6542  | +1.2113e-03 | 6.74e+00 | 8.23e-07 | 0.00e+00 |
# |  610  |  610  | 6546  | +1.2113e-03 | 6.74e+00 | 1.39e-07 | 0.00e+00 |
# |  611  |  611  | 6553  | +1.2113e-03 | 6.74e+00 | 6.37e-08 | 0.00e+00 |
# |  612  |  612  | 6631  | +1.2113e-03 | 6.74e-01 | 6.37e-08 | 0.00e+00 |
# |  613  |  613  | 6689  | +1.2113e-03 | 1.35e+00 | 1.47e-05 | 0.00e+00 |
# |  614  |  614  | 6692  | +1.2113e-03 | 1.35e+00 | 8.76e-06 | 0.00e+00 |
# |  615  |  615  | 6696  | +1.2113e-03 | 1.35e+00 | 3.06e-06 | 0.00e+00 |
# |  616  |  616  | 6702  | +1.2113e-03 | 1.35e+00 | 1.81e-06 | 0.00e+00 |
# |  617  |  617  | 6703  | +1.2113e-03 | 1.35e+00 | 4.21e-07 | 0.00e+00 |
# |  618  |  618  | 6712  | +1.2113e-03 | 1.35e+00 | 4.51e-07 | 0.00e+00 |
# |  619  |  619  | 6715  | +1.2113e-03 | 1.35e+00 | 1.20e-07 | 0.00e+00 |
# |  620  |  620  | 6753  | +1.2113e-03 | 1.35e+00 | 3.59e-05 | 0.00e+00 |
# |  621  |  621  | 6755  | +1.2113e-03 | 1.35e+00 | 6.20e-06 | 0.00e+00 |
# |  622  |  622  | 6758  | +1.2113e-03 | 1.35e+00 | 1.23e-06 | 0.00e+00 |
# |  623  |  623  | 6763  | +1.2113e-03 | 1.35e+00 | 3.45e-07 | 0.00e+00 |
# |  624  |  624  | 6776  | +1.2113e-03 | 1.35e+00 | 6.45e-07 | 0.00e+00 |
# |  625  |  625  | 6777  | +1.2113e-03 | 1.35e+00 | 1.86e-07 | 0.00e+00 |
# |  626  |  626  | 6791  | +1.2113e-03 | 1.35e+00 | 7.52e-08 | 0.00e+00 |
# |  627  |  627  | 6836  | +1.2113e-03 | 1.35e+00 | 8.77e-06 | 0.00e+00 |
# |  628  |  628  | 6838  | +1.2113e-03 | 1.35e+00 | 3.07e-06 | 0.00e+00 |
# |  629  |  629  | 6844  | +1.2113e-03 | 1.35e+00 | 1.00e-06 | 0.00e+00 |
# |  630  |  630  | 6851  | +1.2113e-03 | 1.35e+00 | 1.62e-07 | 0.00e+00 |
# |  631  |  631  | 6856  | +1.2113e-03 | 1.35e+00 | 7.17e-08 | 0.00e+00 |
# |  632  |  632  | 6885  | +1.2113e-03 | 1.35e+00 | 3.41e-06 | 0.00e+00 |
# |  633  |  633  | 6887  | +1.2113e-03 | 1.35e+00 | 6.78e-07 | 0.00e+00 |
# |  634  |  634  | 6890  | +1.2113e-03 | 1.35e+00 | 1.37e-07 | 0.00e+00 |
# |  635  |  635  | 6907  | +1.2113e-03 | 1.35e+00 | 1.13e-07 | 0.00e+00 |
# |  636  |  636  | 6926  | +1.2113e-03 | 1.35e+00 | 1.82e-07 | 0.00e+00 |
# |  637  |  637  | 6933  | +1.2113e-03 | 1.35e+00 | 3.71e-08 | 0.00e+00 |
# |  638  |  638  | 7009  | +1.2113e-03 | 5.87e-01 | 3.71e-08 | 0.00e+00 |
# |  639  |  639  | 7076  | +1.2113e-03 | 1.17e+00 | 2.79e-05 | 0.00e+00 |
# |  640  |  640  | 7079  | +1.2113e-03 | 1.17e+00 | 6.53e-06 | 0.00e+00 |
# |  641  |  641  | 7081  | +1.2113e-03 | 1.17e+00 | 2.41e-06 | 0.00e+00 |
# |  642  |  642  | 7084  | +1.2113e-03 | 1.17e+00 | 3.83e-07 | 0.00e+00 |
# |  643  |  643  | 7101  | +1.2113e-03 | 1.17e+00 | 3.57e-06 | 0.00e+00 |
# |  644  |  644  | 7102  | +1.2113e-03 | 1.17e+00 | 7.02e-07 | 0.00e+00 |
# |  645  |  645  | 7109  | +1.2113e-03 | 1.17e+00 | 2.56e-07 | 0.00e+00 |
# |  646  |  646  | 7128  | +1.2113e-03 | 1.17e+00 | 7.41e-07 | 0.00e+00 |
# |  647  |  647  | 7131  | +1.2113e-03 | 1.17e+00 | 1.34e-07 | 0.00e+00 |
# |  648  |  648  | 7161  | +1.2113e-03 | 1.17e+00 | 2.93e-05 | 0.00e+00 |
# |  649  |  649  | 7162  | +1.2113e-03 | 1.17e+00 | 5.67e-06 | 0.00e+00 |
# |  650  |  650  | 7166  | +1.2113e-03 | 1.17e+00 | 7.46e-07 | 0.00e+00 |
# |  651  |  651  | 7171  | +1.2113e-03 | 1.17e+00 | 1.77e-07 | 0.00e+00 |
# |  652  |  652  | 7185  | +1.2113e-03 | 1.17e+00 | 1.31e-07 | 0.00e+00 |
# |  653  |  653  | 7215  | +1.2113e-03 | 1.17e+00 | 3.25e-06 | 0.00e+00 |
# |  654  |  654  | 7218  | +1.2113e-03 | 1.17e+00 | 7.79e-07 | 0.00e+00 |
# |  655  |  655  | 7222  | +1.2113e-03 | 1.17e+00 | 1.18e-07 | 0.00e+00 |
# ...
# |  785  |  785  | 9413  | +1.2112e-03 | 6.06e-01 | 1.10e-06 | 0.00e+00 |
# |  786  |  786  | 9414  | +1.2112e-03 | 6.06e-01 | 2.21e-07 | 0.00e+00 |
# |  787  |  787  | 9416  | +1.2112e-03 | 6.06e-01 | 3.85e-08 | 0.00e+00 |
# |  788  |  788  | 9438  | +1.2112e-03 | 6.06e-01 | 5.00e-08 | 0.00e+00 |
# |  789  |  789  | 9440  | +1.2112e-03 | 6.06e-01 | 1.28e-08 | 0.00e+00 |
# |  790  |  790  | 9532  | +1.2112e-03 | 6.06e-01 | 1.65e-04 | 0.00e+00 |
# |  791  |  791  | 9533  | +1.2112e-03 | 6.06e-01 | 8.05e-05 | 0.00e+00 |
# |  792  |  792  | 9535  | +1.2112e-03 | 6.06e-01 | 2.35e-05 | 0.00e+00 |
# |  793  |  793  | 9537  | +1.2112e-03 | 6.06e-01 | 2.80e-06 | 0.00e+00 |
# |  794  |  794  | 9541  | +1.2112e-03 | 6.06e-01 | 9.25e-07 | 0.00e+00 |
# |  795  |  795  | 9548  | +1.2112e-03 | 6.06e-01 | 2.22e-07 | 0.00e+00 |
# |  796  |  796  | 9571  | +1.2112e-03 | 6.06e-01 | 9.98e-06 | 0.00e+00 |
# |  797  |  797  | 9572  | +1.2112e-03 | 6.06e-01 | 7.63e-07 | 0.00e+00 |
# |  798  |  798  | 9575  | +1.2112e-03 | 6.06e-01 | 8.02e-08 | 0.00e+00 |
# |  799  |  799  | 9598  | +1.2112e-03 | 6.06e-01 | 6.64e-07 | 0.00e+00 |
# |  800  |  800  | 9601  | +1.2112e-03 | 6.06e-01 | 7.89e-08 | 0.00e+00 |
# |  801  |  801  | 9655  | +1.2112e-03 | 6.06e-01 | 6.56e-05 | 0.00e+00 |
# |  802  |  802  | 9656  | +1.2112e-03 | 6.06e-01 | 9.17e-06 | 0.00e+00 |
# |  803  |  803  | 9657  | +1.2112e-03 | 6.06e-01 | 2.35e-06 | 0.00e+00 |
# |  804  |  804  | 9661  | +1.2112e-03 | 6.06e-01 | 2.70e-07 | 0.00e+00 |
# |  805  |  805  | 9669  | +1.2112e-03 | 6.06e-01 | 3.34e-07 | 0.00e+00 |
# |  806  |  806  | 9670  | +1.2112e-03 | 6.06e-01 | 1.02e-07 | 0.00e+00 |
# |  807  |  807  | 9693  | +1.2112e-03 | 6.06e-01 | 6.10e-07 | 0.00e+00 |
# |  808  |  808  | 9695  | +1.2112e-03 | 6.06e-01 | 8.42e-08 | 0.00e+00 |
# |  809  |  809  | 9701  | +1.2112e-03 | 6.06e-01 | 2.71e-08 | 0.00e+00 |
# |  810  |  810  | 9809  | +1.2112e-03 | 6.06e-02 | 2.71e-08 | 0.00e+00 |
# |  811  |  811  | 9861  | +1.2112e-03 | 4.24e-01 | 1.37e-05 | 0.00e+00 |
# |  812  |  812  | 9862  | +1.2112e-03 | 4.24e-01 | 4.16e-06 | 0.00e+00 |
# |  813  |  813  | 9864  | +1.2112e-03 | 4.24e-01 | 6.63e-07 | 0.00e+00 |
# |  814  |  814  | 9871  | +1.2112e-03 | 4.24e-01 | 8.32e-07 | 0.00e+00 |
# |  815  |  815  | 9874  | +1.2112e-03 | 4.24e-01 | 2.24e-07 | 0.00e+00 |
# |  816  |  816  | 9877  | +1.2112e-03 | 4.24e-01 | 1.00e-07 | 0.00e+00 |
# |  817  |  817  | 9899  | +1.2112e-03 | 4.24e-01 | 2.49e-07 | 0.00e+00 |
# |  818  |  818  | 9905  | +1.2112e-03 | 4.24e-01 | 1.78e-07 | 0.00e+00 |
# |  819  |  819  | 9918  | +1.2112e-03 | 4.24e-01 | 5.52e-07 | 0.00e+00 |
# |  820  |  820  | 9919  | +1.2112e-03 | 4.24e-01 | 1.37e-07 | 0.00e+00 |
# |  821  |  821  | 9926  | +1.2112e-03 | 4.24e-01 | 4.21e-08 | 0.00e+00 |
# |  822  |  822  | 9954  | +1.2112e-03 | 4.24e-01 | 9.62e-07 | 0.00e+00 |
# |  823  |  823  | 9956  | +1.2112e-03 | 4.24e-01 | 2.06e-07 | 0.00e+00 |
# |  824  |  824  | 9960  | +1.2112e-03 | 4.24e-01 | 6.91e-08 | 0.00e+00 |
# |  825  |  825  | 9969  | +1.2112e-03 | 4.24e-01 | 2.07e-08 | 0.00e+00 |
# |  826  |  826  | 10063 | +1.2112e-03 | 2.12e-01 | 2.07e-08 | 0.00e+00 |
# |  827  |  827  | 10151 | +1.2112e-03 | 4.24e-01 | 5.01e-05 | 0.00e+00 |
# |  828  |  828  | 10153 | +1.2112e-03 | 4.24e-01 | 1.02e-05 | 0.00e+00 |
# |  829  |  829  | 10155 | +1.2112e-03 | 4.24e-01 | 1.22e-06 | 0.00e+00 |
# |  830  |  830  | 10166 | +1.2112e-03 | 4.24e-01 | 3.16e-06 | 0.00e+00 |
# |  831  |  831  | 10167 | +1.2112e-03 | 4.24e-01 | 3.48e-07 | 0.00e+00 |
# |  832  |  832  | 10183 | +1.2112e-03 | 4.24e-01 | 1.25e-06 | 0.00e+00 |
# |  833  |  833  | 10186 | +1.2112e-03 | 4.24e-01 | 3.04e-07 | 0.00e+00 |
# |  834  |  834  | 10203 | +1.2112e-03 | 4.24e-01 | 4.12e-06 | 0.00e+00 |
# |  835  |  835  | 10205 | +1.2112e-03 | 4.24e-01 | 4.29e-07 | 0.00e+00 |
# |  836  |  836  | 10222 | +1.2112e-03 | 4.24e-01 | 1.27e-06 | 0.00e+00 |
# |  837  |  837  | 10224 | +1.2112e-03 | 4.24e-01 | 2.95e-07 | 0.00e+00 |
# |  838  |  838  | 10228 | +1.2112e-03 | 4.24e-01 | 4.71e-08 | 0.00e+00 |
# |  839  |  839  | 10264 | +1.2112e-03 | 4.24e-01 | 7.39e-06 | 0.00e+00 |
# |  840  |  840  | 10266 | +1.2112e-03 | 4.24e-01 | 3.21e-07 | 0.00e+00 |
# |  841  |  841  | 10273 | +1.2112e-03 | 4.24e-01 | 2.13e-07 | 0.00e+00 |
# |  842  |  842  | 10278 | +1.2112e-03 | 4.24e-01 | 6.61e-08 | 0.00e+00 |
# |  843  |  843  | 10291 | +1.2112e-03 | 4.24e-01 | 1.90e-07 | 0.00e+00 |
# |  844  |  844  | 10292 | +1.2112e-03 | 4.24e-01 | 3.58e-08 | 0.00e+00 |
# |  845  |  845  | 10321 | +1.2112e-03 | 4.24e-01 | 6.45e-07 | 0.00e+00 |
# |  846  |  846  | 10323 | +1.2112e-03 | 4.24e-01 | 3.09e-08 | 0.00e+00 |
# |  847  |  847  | 10354 | +1.2112e-03 | 4.24e-01 | 2.15e-07 | 0.00e+00 |
# |  848  |  848  | 10357 | +1.2112e-03 | 4.24e-01 | 4.64e-08 | 0.00e+00 |
# |  849  |  849  | 10378 | +1.2112e-03 | 4.24e-01 | 3.29e-07 | 0.00e+00 |
# |  850  |  850  | 10380 | +1.2112e-03 | 4.24e-01 | 1.92e-08 | 0.00e+00 |
# |  851  |  851  | 10479 | +1.2112e-03 | 4.67e-02 | 1.92e-08 | 0.00e+00 |
# |  852  |  852  | 10534 | +1.2112e-03 | 1.34e-01 | 1.50e-05 | 0.00e+00 |
# |  853  |  853  | 10535 | +1.2112e-03 | 1.34e-01 | 5.22e-06 | 0.00e+00 |
# |  854  |  854  | 10537 | +1.2112e-03 | 1.34e-01 | 4.24e-07 | 0.00e+00 |
# |  855  |  855  | 10541 | +1.2112e-03 | 1.34e-01 | 8.42e-08 | 0.00e+00 |
# |  856  |  856  | 10557 | +1.2112e-03 | 1.34e-01 | 1.18e-07 | 0.00e+00 |
# |  857  |  857  | 10568 | +1.2112e-03 | 1.34e-01 | 5.88e-08 | 0.00e+00 |
# |  858  |  858  | 10585 | +1.2112e-03 | 1.34e-01 | 3.39e-07 | 0.00e+00 |
# |  859  |  859  | 10588 | +1.2112e-03 | 1.34e-01 | 5.46e-08 | 0.00e+00 |
# |  860  |  860  | 10605 | +1.2112e-03 | 1.34e-01 | 1.73e-07 | 0.00e+00 |
# |  861  |  861  | 10606 | +1.2112e-03 | 1.34e-01 | 2.81e-08 | 0.00e+00 |
# |  862  |  862  | 10629 | +1.2112e-03 | 1.34e-01 | 3.40e-08 | 0.00e+00 |
# |  863  |  863  | 10638 | +1.2112e-03 | 1.34e-01 | 1.38e-08 | 0.00e+00 |
# |  922  |  922  | 11729 | +1.2112e-03 | 1.32e-01 | 9.85e-08 | 0.00e+00 |
# |  923  |  923  | 11730 | +1.2112e-03 | 1.32e-01 | 6.09e-08 | 0.00e+00 |
# |  924  |  924  | 11731 | +1.2112e-03 | 1.32e-01 | 2.33e-08 | 0.00e+00 |
# |  925  |  925  | 11829 | +1.2112e-03 | 1.32e-01 | 5.11e-05 | 0.00e+00 |
# |  926  |  926  | 11830 | +1.2112e-03 | 1.32e-01 | 1.73e-05 | 0.00e+00 |
# |  927  |  927  | 11832 | +1.2112e-03 | 1.32e-01 | 3.50e-06 | 0.00e+00 |
# |  928  |  928  | 11835 | +1.2112e-03 | 1.32e-01 | 1.54e-06 | 0.00e+00 |
# |  929  |  929  | 11838 | +1.2112e-03 | 1.32e-01 | 5.29e-07 | 0.00e+00 |
# |  930  |  930  | 11844 | +1.2112e-03 | 1.32e-01 | 8.01e-07 | 0.00e+00 |
# |  931  |  931  | 11845 | +1.2112e-03 | 1.32e-01 | 1.86e-07 | 0.00e+00 |
# |  932  |  932  | 11851 | +1.2112e-03 | 1.32e-01 | 7.81e-08 | 0.00e+00 |
# |  933  |  933  | 11869 | +1.2112e-03 | 1.32e-01 | 2.69e-07 | 0.00e+00 |
# |  934  |  934  | 11871 | +1.2112e-03 | 1.32e-01 | 6.83e-08 | 0.00e+00 |
# |  935  |  935  | 11877 | +1.2112e-03 | 1.32e-01 | 2.25e-08 | 0.00e+00 |
# |  936  |  936  | 11967 | +1.2112e-03 | 1.65e-01 | 9.55e-06 | 0.00e+00 |
# |  937  |  937  | 11969 | +1.2112e-03 | 1.65e-01 | 1.87e-06 | 0.00e+00 |
# |  938  |  938  | 11972 | +1.2112e-03 | 1.65e-01 | 3.76e-07 | 0.00e+00 |
# |  939  |  939  | 11978 | +1.2112e-03 | 1.65e-01 | 4.49e-07 | 0.00e+00 |
# |  940  |  940  | 11979 | +1.2112e-03 | 1.65e-01 | 6.56e-08 | 0.00e+00 |
# |  941  |  941  | 11997 | +1.2112e-03 | 1.65e-01 | 9.27e-08 | 0.00e+00 |
# |  942  |  942  | 12000 | +1.2112e-03 | 1.65e-01 | 2.82e-08 | 0.00e+00 |
# |  943  |  943  | 12045 | +1.2112e-03 | 1.65e-01 | 1.78e-06 | 0.00e+00 |
# |  944  |  944  | 12047 | +1.2112e-03 | 1.65e-01 | 1.56e-07 | 0.00e+00 |
# |  945  |  945  | 12050 | +1.2112e-03 | 1.65e-01 | 4.35e-08 | 0.00e+00 |
# |  946  |  946  | 12082 | +1.2112e-03 | 1.65e-01 | 2.73e-07 | 0.00e+00 |
# |  947  |  947  | 12083 | +1.2112e-03 | 1.65e-01 | 2.60e-08 | 0.00e+00 |
# |  948  |  948  | 12104 | +1.2112e-03 | 1.65e-01 | 3.28e-08 | 0.00e+00 |
# |  949  |  949  | 12129 | +1.2112e-03 | 1.65e-01 | 1.01e-07 | 0.00e+00 |
# |  950  |  950  | 12130 | +1.2112e-03 | 1.65e-01 | 2.39e-08 | 0.00e+00 |
# |  951  |  951  | 12148 | +1.2112e-03 | 1.65e-01 | 1.33e-08 | 0.00e+00 |
# |  952  |  952  | 12259 | +1.2112e-03 | 1.65e-01 | 1.20e-04 | 0.00e+00 |
# |  953  |  953  | 12260 | +1.2112e-03 | 1.65e-01 | 2.30e-05 | 0.00e+00 |
# |  954  |  954  | 12262 | +1.2112e-03 | 1.65e-01 | 2.64e-06 | 0.00e+00 |
# |  955  |  955  | 12264 | +1.2112e-03 | 1.65e-01 | 4.16e-07 | 0.00e+00 |
# |  956  |  956  | 12270 | +1.2112e-03 | 1.65e-01 | 6.44e-08 | 0.00e+00 |
# |  957  |  957  | 12295 | +1.2112e-03 | 1.65e-01 | 4.26e-07 | 0.00e+00 |
# |  958  |  958  | 12298 | +1.2112e-03 | 1.65e-01 | 1.12e-07 | 0.00e+00 |
# |  959  |  959  | 12317 | +1.2112e-03 | 1.65e-01 | 6.46e-08 | 0.00e+00 |
# |  960  |  960  | 12342 | +1.2112e-03 | 1.65e-01 | 7.65e-07 | 0.00e+00 |
# |  961  |  961  | 12343 | +1.2112e-03 | 1.65e-01 | 2.70e-07 | 0.00e+00 |
# |  962  |  962  | 12346 | +1.2112e-03 | 1.65e-01 | 4.28e-08 | 0.00e+00 |
# |  963  |  963  | 12371 | +1.2112e-03 | 1.65e-01 | 3.67e-07 | 0.00e+00 |
# |  964  |  964  | 12373 | +1.2112e-03 | 1.65e-01 | 5.04e-08 | 0.00e+00 |
# |  965  |  965  | 12433 | +1.2112e-03 | 1.65e-01 | 2.08e-05 | 0.00e+00 |
# |  966  |  966  | 12434 | +1.2112e-03 | 1.65e-01 | 4.69e-06 | 0.00e+00 |
# |  967  |  967  | 12436 | +1.2112e-03 | 1.65e-01 | 4.15e-07 | 0.00e+00 |
# |  968  |  968  | 12440 | +1.2112e-03 | 1.65e-01 | 8.85e-08 | 0.00e+00 |
# |  969  |  969  | 12465 | +1.2112e-03 | 1.65e-01 | 6.78e-08 | 0.00e+00 |
# |  970  |  970  | 12476 | +1.2112e-03 | 1.65e-01 | 4.45e-08 | 0.00e+00 |
# |  971  |  971  | 12501 | +1.2112e-03 | 1.65e-01 | 4.57e-07 | 0.00e+00 |
# |  972  |  972  | 12502 | +1.2112e-03 | 1.65e-01 | 2.91e-08 | 0.00e+00 |
# |  973  |  973  | 12527 | +1.2112e-03 | 1.65e-01 | 4.14e-08 | 0.00e+00 |
# |  974  |  974  | 12530 | +1.2112e-03 | 1.65e-01 | 1.97e-08 | 0.00e+00 |
# |  975  |  975  | 12638 | +1.2112e-03 | 8.23e-02 | 1.97e-08 | 0.00e+00 |
# |  976  |  976  | 12696 | +1.2112e-03 | 4.11e-02 | 1.97e-08 | 0.00e+00 |
# |  977  |  977  | 12756 | +1.2112e-03 | 8.23e-02 | 1.30e-05 | 0.00e+00 |
# |  978  |  978  | 12758 | +1.2112e-03 | 8.23e-02 | 6.53e-06 | 0.00e+00 |
# |  979  |  979  | 12760 | +1.2112e-03 | 8.23e-02 | 9.26e-07 | 0.00e+00 |
# |  980  |  980  | 12764 | +1.2112e-03 | 8.23e-02 | 3.16e-07 | 0.00e+00 |
# |  981  |  981  | 12775 | +1.2112e-03 | 8.23e-02 | 8.68e-07 | 0.00e+00 |
# |  982  |  982  | 12776 | +1.2112e-03 | 8.23e-02 | 1.30e-07 | 0.00e+00 |
# |  983  |  983  | 12783 | +1.2112e-03 | 8.23e-02 | 3.58e-08 | 0.00e+00 |
# |  984  |  984  | 12824 | +1.2112e-03 | 8.23e-02 | 1.39e-06 | 0.00e+00 |
# |  985  |  985  | 12825 | +1.2112e-03 | 8.23e-02 | 2.57e-07 | 0.00e+00 |
# |  986  |  986  | 12828 | +1.2112e-03 | 8.23e-02 | 3.75e-08 | 0.00e+00 |
# |  987  |  987  | 12832 | +1.2112e-03 | 8.23e-02 | 2.22e-08 | 0.00e+00 |
# |  988  |  988  | 12905 | +1.2112e-03 | 5.76e-01 | 4.97e-05 | 0.00e+00 |
# |  989  |  989  | 12906 | +1.2112e-03 | 5.76e-01 | 6.10e-06 | 0.00e+00 |
# |  990  |  990  | 12908 | +1.2112e-03 | 5.76e-01 | 4.36e-07 | 0.00e+00 |
# |  991  |  991  | 12911 | +1.2112e-03 | 5.76e-01 | 1.20e-07 | 0.00e+00 |
# |  992  |  992  | 12926 | +1.2112e-03 | 5.76e-01 | 3.87e-07 | 0.00e+00 |
# |  993  |  993  | 12927 | +1.2112e-03 | 5.76e-01 | 3.68e-08 | 0.00e+00 |
# |  994  |  994  | 12961 | +1.2112e-03 | 5.76e-01 | 2.38e-06 | 0.00e+00 |
# |  995  |  995  | 12963 | +1.2112e-03 | 5.76e-01 | 9.99e-08 | 0.00e+00 |
# |  996  |  996  | 12974 | +1.2112e-03 | 5.76e-01 | 2.04e-07 | 0.00e+00 |
# |  997  |  997  | 12975 | +1.2112e-03 | 5.76e-01 | 3.71e-08 | 0.00e+00 |
# |  998  |  998  | 13001 | +1.2112e-03 | 5.76e-01 | 1.37e-07 | 0.00e+00 |
# |  999  |  999  | 13004 | +1.2112e-03 | 5.76e-01 | 2.34e-08 | 0.00e+00 |
# | 1000  | 1000  | 13023 | +1.2112e-03 | 5.76e-01 | 9.01e-08 | 0.00e+00 |
#
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1000, function evaluations: 1000, CG iterations: 13023, optimality: 9.01e-08, constraint violation: 0.00e+00, execution time: 9.6e+02 s.

# %%
# with open('./thetas/memory_tdcis/120stepsmemory_2kstepspropagation_linear_model_theta.npz','wb') as f:
#     np.save(f,trainedtheta)

# %%
# for i in inds:
#     fig, axs = plt.subplots(2, 2, figsize=(10,8))
#     #axs[0,0].plot(mlprop[:,0,0].real, color='red')
#     axs[0,0].plot(jnp.real(trnden[i][:mynumsteps+1,0,0]),color='black')
#     axs[0,0].set_title('P'+str(0)+str(0)+' Real')

#     #axs[0,1].plot(mlprop[:,0,1].real, color='red')
#     axs[0,1].plot(jnp.real(trnden[i][:mynumsteps+1,0,1]),color='black')
#     axs[0,1].set_title('P'+str(0)+str(1)+' Real')

#     #axs[1,0].plot(mlprop[:,0,1].imag, color='red')
#     axs[1,0].plot(jnp.imag(trnden[i][:mynumsteps+1,0,1]),color='black')
#     axs[1,0].set_title('P'+str(0)+str(1)+' Imaginary')

#     #axs[1,1].plot(mlprop[:,1,1].real, color='red')
#     axs[1,1].plot(jnp.real(trnden[i][:mynumsteps+1,1,1]),color='black')
#     axs[1,1].set_title('P'+str(1)+str(1)+' Real')
#     plt.legend(['ML Prop', 'Ground Truth'])
#     #plt.show()
#     #plt.close()

# %%
trnden = jnp.array(np.load('./tdcis_data/tdcis_dt0.0082680.npz'))
trndentdhf = jnp.array(np.load('./tdhf_data/rt-tdhf_forcing_full_finedt.npz'))
trnfrq = jnp.array(np.load('./tdcis_data/tdcis_trnfreq_dt0.008268.npz'))
trnamp = jnp.array(np.load('./tdcis_data/tdcis_trnamp_dt0.008268.npz'))
trntme = jnp.array(np.load('./tdcis_data/tdcis_trntme_dt0.008268.npz'))

# %%
trnden.shape
# Out:
# (301, 10000, 2, 2)

# %%
inds
# Out:
# array([140])

# %%
i = 140
mynumsteps = 1000
ic = trnden[i][0,:,:].reshape((-1))
#can try propagating ondifferent amt of steps
mlprop = MMUT_Prop_Memory(trainedtheta, ic, dt=dt, ntvec=mynumsteps, tmeoff=trntme[i], fldfrq=trnfrq[i], fldamp=trnamp[i])

# %%
print(jnp.mean(jnp.abs(mlprop - trnden[i][:mynumsteps+1,:,:])**2))
fig, axs = plt.subplots(2, 2, figsize=(10,8))
axs[0,0].plot(mlprop[:,0,0].real, color='red')
axs[0,0].plot(jnp.real(trnden[i][:mynumsteps+1,0,0]),color='black')
axs[0,0].set_title('P'+str(0)+str(0)+' Real')

axs[0,1].plot(mlprop[:,0,1].real, color='red')
axs[0,1].plot(jnp.real(trnden[i][:mynumsteps+1,0,1]),color='black')
axs[0,1].set_title('P'+str(0)+str(1)+' Real')

axs[1,0].plot(mlprop[:,0,1].imag, color='red')
axs[1,0].plot(jnp.imag(trnden[i][:mynumsteps+1,0,1]),color='black')
axs[1,0].set_title('P'+str(0)+str(1)+' Imaginary')

axs[1,1].plot(mlprop[:,1,1].real, color='red')
axs[1,1].plot(jnp.real(trnden[i][:mynumsteps+1,1,1]),color='black')
axs[1,1].set_title('P'+str(1)+str(1)+' Real')
#plt.savefig('./figures/memory/polynomial_model_5stepsmemory_2kprop.pdf')
plt.legend(['ML Prop', 'Ground Truth'])
plt.show()
plt.close()
# Out:
# 0.0002952642910026271

# %%
# 1k steps:
# TDHF Hamiltonian true theta loss: 0.010243213034352787
# memory 1-step training loss: 0.00253650274771213
# memory 2-step training loss: 0.002497673708462945
# memory 5-step training loss: 0.0024484148373247468

# 500 steps:
# TDHF Hamiltonian true theta loss: 0.0026438892383214957
# memory 1-step training loss: 9.210085073722918e-06
# memory 2-step training loss: 9.16744614942511e-06
# memory 5-step training loss: 9.16539059978862e-06
 
# 2000 steps:
# TDHF Hamiltonian true theta loss: 0.020693919900817134
# memory 1-step training loss: 0.004882286574078557
# memory 2-step training loss: 0.004876315008180665
# memory 5-step training loss:  0.004874786252107475

# %%
losses500steps = [0.0026438892383214957, 9.210085073722918e-06, 9.16744614942511e-06,  9.16539059978862e-06 ]
losses1ksteps = [0.010243213034352787,  0.00253650274771213, 0.002497673708462945, 0.0024484148373247468]
losses2ksteps = [ 0.020693919900817134, 0.004882286574078557, 0.004876315008180665, 0.004874786252107475]

# %%
# x = [1,2,5]
# xi = list(range(len(x)))
# plt.plot(xi,losses500steps[1:]);
# plt.xticks(xi,x);
# plt.ylabel('Training Loss');
# plt.xlabel('Steps of Memory');
# plt.title('500 Propagation Steps Losses (True TDHF Theta Loss: 0.0026438892)');
# plt.savefig('./figures/500steps_memory_losses_highamp.pdf')

# %%
# x = [1,2,5]
# xi = list(range(len(x)))
# plt.plot(xi,losses1ksteps[1:]);
# plt.xticks(xi,x);
# plt.ylabel('Training Loss');
# plt.xlabel('Steps of Memory');
# plt.title('1000 Propagation Steps Losses (True TDHF Theta Loss:0.010243213)');
# plt.savefig('./figures/1ksteps_memory_losses_highamp.pdf')

# %%
# x = [1,2,5]
# xi = list(range(len(x)))
# plt.plot(xi,losses2ksteps[1:]);
# plt.xticks(xi,x);
# plt.ylabel('Training Loss');
# plt.xlabel('Steps of Memory');
# plt.title('2000 Propagation Steps Losses (True TDHF Theta Loss:0.02069391)');
# plt.savefig('./figures/2ksteps_memory_losses_highamp.pdf')

# %%
i = 145
ic = trnden[i][0,:,:].reshape((-1))
mlprop = MMUT_Prop_Memory(trainedtheta, ic, dt=dt, ntvec=mynumsteps, tmeoff=trntme[i], fldfrq=trnfrq[i], fldamp=trnamp[i])

# %%
print(jnp.mean(jnp.abs(mlprop - trnden[i][:mynumsteps+1,:,:])**2))
print(jnp.mean(jnp.abs(mlprop - trndentdhf[i][:mynumsteps+1,:,:])**2))
fig, axs = plt.subplots(2, 2, figsize=(10,8))
axs[0,0].plot(mlprop[:,0,0].real, color='red')
axs[0,0].plot(jnp.real(trnden[i][:mynumsteps+1,0,0]),color='black')
axs[0,0].plot(jnp.real(trndentdhf[i][:mynumsteps+1,0,0]))
axs[0,0].set_title('P'+str(0)+str(0)+' Real')

axs[0,1].plot(mlprop[:,0,1].real, color='red')
axs[0,1].plot(jnp.real(trnden[i][:mynumsteps+1,0,1]),color='black')
axs[0,1].plot(jnp.real(trndentdhf[i][:mynumsteps+1,0,1]))
axs[0,1].set_title('P'+str(0)+str(1)+' Real')

axs[1,0].plot(mlprop[:,0,1].imag, color='red')
axs[1,0].plot(jnp.imag(trnden[i][:mynumsteps+1,0,1]),color='black')
axs[1,0].plot(jnp.imag(trndentdhf[i][:mynumsteps+1,0,1]))
axs[1,0].set_title('P'+str(0)+str(1)+' Imaginary')

axs[1,1].plot(mlprop[:,1,1].real, color='red')
axs[1,1].plot(jnp.real(trnden[i][:mynumsteps+1,1,1]),color='black')
axs[1,1].plot(jnp.real(trndentdhf[i][:mynumsteps+1,1,1]))
axs[1,1].set_title('P'+str(1)+str(1)+' Real')

plt.legend(['ML Prop', 'Ground Truth (TDCIs)', 'Ground Truth (TDHF)'])
#plt.legend(['Ground Truth (TDCIs)', 'Ground Truth (TDHF)'])
plt.show()
plt.close()
# Out:
# 0.07297552750011936
# 0.14610325710346284

# %%
# # pick one training trajectory, and for this trajectory, 
# # plot the MSE at each point in time between
# # (1) mlprop, the result we get by propagating using the learned theta from optimization --- "res.x",
# # (2) the ground truth training trajectory
# for ii in range(140,160):
#     i = ii
#     ic = trnden[i][0,:,:].reshape((-1))
#     mlprop = MMUT_Prop_HSB(jnp.array(res.x), 
#                            ic, dt=dt, ntvec=mynumsteps, tmeoff=trntme[i], fldfrq=trnfrq[i], fldamp=trnamp[i])
#     #print(mlprop.shape)
#     #print(trnden[i][:mynumsteps+1,:,:].shape)
#     print(trnfrq[i],trnamp[i])
#     print(jnp.mean(jnp.abs(mlprop - trnden[i][:mynumsteps+1,:,:])**2))
#     print('=============================================')
#     plt.figure(figsize=(6,4))
#     plt.plot(jnp.mean(jnp.abs(mlprop-trnden[i][:mynumsteps+1,:,:])**2,axis=(1,2)))
# plt.show()

# %%
# compute and return all the densities **and** all the Hamiltonians along one trajectory!
def MMUT_Save_Ham(theta, initial_density, dt=0.08268, ntvec=2000,
                  tmeoff=1, fldfrq=1, fldamp=1, norm_direc=jnp.array([0.0,0.0,1.0])):
    tvec = dt*jnp.arange(ntvec)
    P0 = initial_density.reshape((drc, drc))
    propagated_dens = [P0]
    H0 = MLham(theta,0.0,P0.real, P0.imag,fldfrq,fldamp,tmeoff,norm_direc)
    H0 = H0[0] + 1.0j*H0[1]
    propagated_hams = [H0]
    evals, evecs = jnp.linalg.eigh(H0)
    U0 = evecs @ jnp.diag(jnp.exp(-1j*dt*evals)) @ evecs.conj().T
    P1 = U0 @ P0 @ U0.conj().T
    propagated_dens.append( P1 )
    def bodyfun(i, intup):
        dl, hl = intup
        P0 = dl[i, :, :]
        P1 = dl[i+1, :, :]
        H1 = MLham(theta,(i+1.0)*dt,P1.real, P1.imag,fldfrq,fldamp,tmeoff,norm_direc)
        H1 = H1[0] + 1.0j*H1[1]
        evals, evecs = jnp.linalg.eigh(H1)
        U1 = evecs @ jnp.diag(jnp.exp(-2j*dt*evals)) @ evecs.conj().T
        P2 = U1 @ P0 @ U1.conj().T
        return (dl.at[i+2].set( P2 ), hl.at[i+1].set( H1 ))
    
    alldens = jnp.concatenate([jnp.stack(propagated_dens), jnp.zeros((ntvec-1, drc, drc))], axis=0)
    allhams = jnp.concatenate([jnp.stack(propagated_hams), jnp.zeros((ntvec-1, drc, drc))], axis=0)
    fdh = lax.fori_loop(0, ntvec-1, bodyfun, (alldens, allhams))
    
    return fdh

# %%
# compute mean square commutator errors for one trajectory
def commutatorerror(theta, i):
    ic = trnden[i][0,:,:].reshape((-1))
    mynumsteps = 4000
    mydenham = MMUT_Save_Ham(theta, ic, dt=dt, ntvec=mynumsteps, tmeoff=trntme[i], fldfrq=trnfrq[i], fldamp=trnamp[i])
    trdenham = MMUT_Save_Ham(thetatrue, ic, dt=dt, ntvec=mynumsteps, tmeoff=trntme[i], fldfrq=trnfrq[i], fldamp=trnamp[i])

    mycom = jnp.einsum('aij,ajk->aik',mydenham[1],mydenham[0][:-1,:,:]) - jnp.einsum('aij,ajk->aik',mydenham[0][:-1,:,:],mydenham[1])
    trcom = jnp.einsum('aij,ajk->aik',trdenham[1],trdenham[0][:-1,:,:]) - jnp.einsum('aij,ajk->aik',trdenham[0][:-1,:,:],trdenham[1])

    return jnp.mean(jnp.square(jnp.abs(mycom - trcom)))

# %%
# many trajectory version
vcommutatorerror = vmap(commutatorerror, (None, 0))
jvcommutatorerror = jit(vcommutatorerror)

# %%
# evaluate commutator errors on training set
allcommerrs = jvcommutatorerror(jnp.array(res.x), jnp.arange(100))
# Out:
# ---------------------------------------------------------------------------
# InconclusiveDimensionOperation            Traceback (most recent call last)
# Cell In[51], line 2
#       1 # evaluate commutator errors on training set
# ----> 2 allcommerrs = jvcommutatorerror(jnp.array(res.x), jnp.arange(100))
#
#     [... skipping hidden 17 frame]
#
# Cell In[49], line 6, in commutatorerror(theta, i)
#       4 mynumsteps = 4000
#       5 mydenham = MMUT_Save_Ham(theta, ic, dt=dt, ntvec=mynumsteps, tmeoff=trntme[i], fldfrq=trnfrq[i], fldamp=trnamp[i])
# ----> 6 trdenham = MMUT_Save_Ham(thetatrue, ic, dt=dt, ntvec=mynumsteps, tmeoff=trntme[i], fldfrq=trnfrq[i], fldamp=trnamp[i])
#       8 mycom = jnp.einsum('aij,ajk->aik',mydenham[1],mydenham[0][:-1,:,:]) - jnp.einsum('aij,ajk->aik',mydenham[0][:-1,:,:],mydenham[1])
#       9 trcom = jnp.einsum('aij,ajk->aik',trdenham[1],trdenham[0][:-1,:,:]) - jnp.einsum('aij,ajk->aik',trdenham[0][:-1,:,:],trdenham[1])
#
# Cell In[48], line 7, in MMUT_Save_Ham(theta, initial_density, dt, ntvec, tmeoff, fldfrq, fldamp, norm_direc)
#       5 P0 = initial_density.reshape((drc, drc))
#       6 propagated_dens = [P0]
# ----> 7 H0 = MLham(theta,0.0,P0.real, P0.imag,fldfrq,fldamp,tmeoff,norm_direc)
#       8 H0 = H0[0] + 1.0j*H0[1]
#       9 propagated_hams = [H0]
#
# Cell In[11], line 15, in MLham(theta, t, x, y, fldfrq, fldamp, tmeoff, norm_direc)
#      13 gamma0p = theta[drc**2:2*drc**2].reshape((drc**2))
#      14 beta1p = theta[2*drc**2:2*drc**2+drc**4].reshape((drc**2,drc**2))
# ---> 15 gamma1p = theta[2*drc**2+drc**4: 2*drc**2+2*drc**4].reshape((drc**2,drc**2))
#      16 beta2p = theta[2*drc**2+2*drc**4:2*drc**2+3*drc**4].reshape((drc**2,drc**2))
#      17 gamma2p = theta[2*drc**2+3*drc**4: 2*drc**2+4*drc**4].reshape((drc**2,drc**2))
#
# File ~/.local/perlmutter/tensorflow2.9.0/lib/python3.9/site-packages/jax/_src/numpy/lax_numpy.py:767, in _reshape(a, order, *args)
#     765 newshape = _compute_newshape(a, args[0] if len(args) == 1 else args)
#     766 if order == "C":
# --> 767   return lax.reshape(a, newshape, None)
#     768 elif order == "F":
#     769   dims = np.arange(ndim(a))[::-1]
#
#     [... skipping hidden 11 frame]
#
# File ~/.local/perlmutter/tensorflow2.9.0/lib/python3.9/site-packages/jax/core.py:1679, in DimensionHandler.divide_shape_sizes(self, s1, s2)
#    1677   return 1
#    1678 if sz1 % sz2:
# -> 1679   raise InconclusiveDimensionOperation(f"Cannot divide evenly the sizes of shapes {tuple(s1)} and {tuple(s2)}")
#    1680 return sz1 // sz2
#
# InconclusiveDimensionOperation: Cannot divide evenly the sizes of shapes (8,) and (4, 4)

# %%
# min, mean, and max commutator error
print(jnp.min(allcommerrs), jnp.mean(allcommerrs), jnp.max(allcommerrs))
