# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
outpath = './nonlinhamtest/'

# %%
traj = np.load(outpath + 'testp2.npz')['traj']
traj.shape

# %%
for i in range(2):
    for j in range(2):
        plt.plot(np.abs(traj[:,i,j]))
        plt.show()
